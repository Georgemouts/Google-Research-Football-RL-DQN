# %%
#https://www.kaggle.com/piotrstanczyk/gfootball-template-bot  G-FOOTBALL TEMPLATE BOT
# Install:
# Kaggle environments.
#!git clone https://github.com/Kaggle/kaggle-environments.git
#!cd kaggle-environments && pip install .

# GFootball environment.
# !apt-get update -y
# !apt-get install -y libsdl2-gfx-dev libsdl2-ttf-dev

# Make sure that the Branch in git clone and in wget call matches !!
# !git clone -b v5 https://github.com/Georgemouts/football.git #https://github.com/google-research/football.git  
# !mkdir -p football/third_party/gfootball_engine/lib

# !wget https://storage.googleapis.com/gfootball/prebuilt_gameplayfootball_v2.8.so -O football/third_party/gfootball_engine/lib/prebuilt_gameplayfootball.so
# !cd football && GFOOTBALL_USE_PREBUILT_SO=1 pip3 install .

# !pip install utils
#!pip install learning
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:6 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsdl2-gfx-dev is already the newest version (1.0.4+dfsg-1).
# libsdl2-ttf-dev is already the newest version (2.0.14+dfsg1-2).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 52 not upgraded.
# fatal: destination path 'football' already exists and is not an empty directory.
# --2022-05-11 10:06:00--  https://storage.googleapis.com/gfootball/prebuilt_gameplayfootball_v2.8.so
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.142.128, 173.194.202.128, 173.194.203.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.142.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45403632 (43M) [application/octet-stream]
# Saving to: ‘football/third_party/gfootball_engine/lib/prebuilt_gameplayfootball.so’
#
# football/third_part 100%[===================>]  43.30M  57.2MB/s    in 0.8s
#
# 2022-05-11 10:06:01 (57.2 MB/s) - ‘football/third_party/gfootball_engine/lib/prebuilt_gameplayfootball.so’ saved [45403632/45403632]
#
# Processing /content/football
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Requirement already satisfied: pygame>=1.9.6 in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (2.1.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (4.1.2.30)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (5.4.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (1.21.6)
# Requirement already satisfied: gym<=0.21.0 in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (0.17.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (1.0.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (0.37.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym<=0.21.0->gfootball==2.10.3) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym<=0.21.0->gfootball==2.10.3) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym<=0.21.0->gfootball==2.10.3) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym<=0.21.0->gfootball==2.10.3) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py->gfootball==2.10.3) (1.15.0)
# Building wheels for collected packages: gfootball
#   Building wheel for gfootball (setup.py) ... done
#   Created wheel for gfootball: filename=gfootball-2.10.3-cp37-cp37m-linux_x86_64.whl size=24207444 sha256=81f8b096507413c48531042ea9196c17afe5bc1c5e1cc755408abc5ff4847bb2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7vrzyqfp/wheels/bb/c2/92/82a23d0c207f5497a23f4316675eb1629e6be474bd2c3be61a
# Successfully built gfootball
# Installing collected packages: gfootball
#   Attempting uninstall: gfootball
#     Found existing installation: gfootball 2.10.3
#     Uninstalling gfootball-2.10.3:
#       Successfully uninstalled gfootball-2.10.3
# Successfully installed gfootball-2.10.3
# Requirement already satisfied: utils in /usr/local/lib/python3.7/dist-packages (1.0.1)

# %%
#from gfootball.env.football_env import FootballEnv
#from kaggle_environments import make
from gfootball.env.config import Config
import gfootball.env as football_env

#import dqn libraries
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim 
import numpy as np
import pandas as pd
import itertools
import utils
import random
from collections import deque
import matplotlib.pyplot as plt
#from utils import plot_learning_curve
#import env 
import gym
import gfootball 
import math

# %%
env = football_env.create_environment(env_name ='academy_empty_goal',render=False,representation='simple115v2')
new_observation,reward,done,info = env.step(5)
print(new_observation)
# Out:
# array([ 5.5872026e-04,  4.9603988e-11,  2.6072832e-03,  2.1274933e-11,
#         2.0000000e-02, -0.0000000e+00,  1.1059734e-01, -0.0000000e+00,
#         0.0000000e+00, -1.9182914e-03], dtype=float32)

# %%
class DeepQNetwork(nn.Module):
  def __init__(self,lr,input_dims,fc1_dims,fc2_dims,fc3_dims,n_actions):
    super(DeepQNetwork,self).__init__()
   # self.lr=lr
    self.input_dims=input_dims
    self.fc1_dims=fc1_dims
    self.fc2_dims=fc2_dims
    self.fc3_dims=fc3_dims
    self.n_actions=n_actions
    
    self.fc1=nn.Linear(*self.input_dims,self.fc1_dims) #pass list of observations as input
    self.fc2=nn.Linear(self.fc1_dims,self.fc2_dims)
    self.fc3=nn.Linear(self.fc2_dims,self.fc3_dims)
    self.fc4=nn.Linear(self.fc3_dims,self.n_actions) #output number action

    self.optimizer = optim.Adam(self.parameters(),lr=lr)
    self.loss=nn.MSELoss()
    self.device =T.device('cuda:0' if T.cuda.is_available() else 'cpu' )
    self.to(self.device)

  def forward(self,state):
   
    x=F.relu(self.fc1(state))
    x=F.relu(self.fc2(x))
    x=F.relu(self.fc3(x))
    actions=self.fc4(x)
      
    return actions

# %%
class All_prints():
  
  def __init___(self,step):
    self.step=step
    #self.RewBuffer = RewBuffer
    self.reward=reward

  def printstats(self,step,rew_list,eps_reward,epsilon):  #Kaleitai otan ginei done , diladi otan teleiosei ena paixnidi
    self.step=step
    self.rew_list=rew_list
    self.eps_reward=eps_reward
    self.epsilon=epsilon
    print("-->Episode:",i%3000 + 1,"\t","Episode Reward:",eps_reward,"\t Epsilon",agent.epsilon,"<--")
    #print("Step",step)
    print("lista apo rewards mexri tora" ,self.rew_list)
    print("Avg reward", np.mean(self.rew_list))
    print("---------------------------------------------------")

  def print_who_scored(self, reward):
    self.reward=reward
    if(self.reward==1):
      print("our team scored !!!")
    elif(self.reward ==-1):
      print("opponent team scored")
    
    
 
  def rew_graph(self,rew_list,num_of_eps):
      self.rew_list=rew_list
      
      self.num_of_eps=num_of_eps
      
      eps_list=list(range(1,self.num_of_eps+1))#pairnei to proto , den pairnei to teleytaio
      
      plt.plot(eps_list,self.rew_list)
      plt.xlabel('Episode')
      plt.ylabel('Rewards')
      plt.grid(True)
      plt.show()


  def score_graph(self,score_list,num_of_eps):
      self.score_list=score_list
      
      self.num_of_eps=num_of_eps
      
      eps_list=list(range(1,self.num_of_eps+1))#pairnei to proto , den pairnei to teleytaio
      
      plt.plot(eps_list,self.score_list)
      plt.xlabel('Episode')
      plt.ylabel('Score')
      plt.grid(True)
      plt.show()

# %%
class Agent():
  def __init__(self,gamma,epsilon, lr , input_dims , batch_size ,n_actions, max_mem_size = 10000  , eps_end=0.01 , eps_dec = 5e-4):
    self.gamma=gamma
    self.epsilon =epsilon
    self.lr=lr
    self.eps_min=eps_end
    self.eps_dec=eps_dec
   
    self.action_space =[i for i in range(n_actions)]
    self.mem_size = max_mem_size
    self.batch_size = batch_size
    self.n_actions=n_actions
    self.mem_cntr =0 # keep track of the position of first available memory 

    self.Q_eval = DeepQNetwork(self.lr,n_actions=n_actions,input_dims= input_dims, fc1_dims=20, fc2_dims=20 , fc3_dims=20)

    self.state_memory = np.zeros((self.mem_size,*input_dims),dtype =np.float32)
    self.new_state_memory= np.zeros((self.mem_size , *input_dims),dtype=np.float32)

    self.action_memory=np.zeros(self.mem_size , dtype=np.int32) #discrete actions (19)
    self.reward_memory=np.zeros(self.mem_size,dtype= np.float32)
    self.terminal_memory= np.zeros(self.mem_size,dtype=bool)


  def store_transition(self,state,action,reward,new_state , done ):
    index = self.mem_cntr% self.mem_size

    self.state_memory[index]= state
    self.new_state_memory[index]= new_state
    self.reward_memory[index]= reward
    self.action_memory[index]= action  #which action is taken 
    self.terminal_memory[index]= done

    self.mem_cntr +=1
    

  def choose_action(self,observation):
    if np.random.random()> self.epsilon:
      
      state =T.tensor([observation]).to(self.Q_eval.device) #turn observation to tensor and send it to device for computations
      action_list = self.Q_eval.forward(state) #returns the values of each action
      action = T.argmax(action_list).item()
      #print("exploit:",action)
    else:     #
      
      action = np.random.choice(self.action_space)
      #print("explore:",action)
    return action

  def learn(self):    #fill batch size then learn 
    if self.mem_cntr < self.batch_size :
      return
    
    
    self.Q_eval.optimizer.zero_grad()

    #calculate the position of max memory / extract subset of max memories
    max_mem =min(self.mem_cntr , self.mem_size)
    


    batch=np.random.choice(max_mem,self.batch_size,replace=False) #We dont keep selecting the same memories more than once
     
    #batch = np.random.permutation(max_mem)[:self.batch_size]
    #mem = np.array(exp_buffer)[perm_batch]

    #batch=np.random.choice(max_mem,self.batch_size,replace=False)
    batch_index = np.arange(self.batch_size , dtype=np.int32)

    state_batch=T.tensor(self.state_memory[batch]).to(self.Q_eval.device) #make numpy array a pytorch tensor
    new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
    reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
    terminal_batch= T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)

    action_batch = self.action_memory[batch] 
  
    q_eval = self.Q_eval.forward(state_batch)[batch_index,action_batch] #EXEI THEMA
    q_next = self.Q_eval.forward(new_state_batch)

    q_next[terminal_batch] = 0.0
    q_target = reward_batch +self.gamma * T.max(q_next,dim=1)[0] #max value of next state

    loss = self.Q_eval.loss(q_target,q_eval).to(self.Q_eval.device)
    loss.backward()
    self.Q_eval.optimizer.step()

    self.epsilon = self.epsilon - self.eps_dec if (self.epsilon > self.eps_min)  else self.eps_min
    """batch = np.random.permutation(max_mem)[:self.batch_size]
    for i in range(self.mem_size//self.batch_size):
      #batch=np.random.choice(max_mem,self.batch_size,replace=False) #We dont keep selecting the same memories more than once
     
      batch = np.random.permutation(max_mem)[:self.batch_size]
      #mem = np.array(exp_buffer)[perm_batch]

      #batch=np.random.choice(max_mem,self.batch_size,replace=False)
      batch_index = np.arange(self.batch_size , dtype=np.int32)

      state_batch=T.tensor(self.state_memory[batch]).to(self.Q_eval.device) #make numpy array a pytorch tensor
      new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
      reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
      terminal_batch= T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)

      action_batch = self.action_memory[batch] 
    
      q_eval = self.Q_eval.forward(state_batch)[batch_index,action_batch] #EXEI THEMA
      q_next = self.Q_eval.forward(new_state_batch)

      q_next[terminal_batch] = 0.0
      q_target = reward_batch +self.gamma * T.max(q_next,dim=1)[0] #max value of next state

      loss = self.Q_eval.loss(q_target,q_eval).to(self.Q_eval.device)
      loss.backward()
      self.Q_eval.optimizer.step()

      self.epsilon = self.epsilon - self.eps_dec if (self.epsilon > self.eps_min)  else self.eps_min
      """

# %%
#TODO: NA BGALO TON PAIKTI

#if __name__ == '__main__':
#env = football_env.create_environment(env_name ='11_vs_11_easy_stochastic',render=False,representation='simple115')  #List with the 115 states 
env = football_env.create_environment(env_name ='academy_empty_goal',render=False,representation='simple115v2')  #List with the 115 states 
#env = gym.make("GFootball-11_vs_11_kaggle-simple115v2-v0") #List with the 115 states
#env = football_env.create_environment(env_name ='academy_single_goal_versus_lazy',render=False,representation='simple115')
#env = football_env.create_environment(env_name ='academy_pass_and_shoot_with_keeper',render=False,representation='simple115')
#env = football_env.create_environment(env_name ='academy_empty_goal',render=False,representation='simple115')  #List with the 115 states 

#CUSTOMIZE ACTION LIST AND OBSERVATIONS
Action_list=[4,5,6,12]

#Create Objects

agent = Agent(gamma=0.99,epsilon=1.0 ,batch_size = 128 ,lr=0.00015 ,input_dims= [10], n_actions = len(Action_list) )# batch = best 256
all_prints = All_prints()
#cus_rew =Custom_Rewards()

scores,ep_history =[],[]

steps=0
terminal =0
episode =0
shout =0


num_of_eps = 1000
eps_rew=0
rew_list =[]
score_list = []
step_list =[]
for i in range(num_of_eps) : 
  score =0 
  done=False 
  observation =env.reset()
  act =0 #first action will be to move right 
  shout=0 #mporei na kanei shout 1 fora se kathe ep
  while not done:

    #CUSTOMIZE ACTIONS HERE 
    #An einai i mpala sto 0.5 kai exo katoxi kane shout diladi action 12
    
    #print("------------")
    #print("Ball X-Y-Z Axis",observation[88],observation[89],observation[90],"||","direct",observation[91],observation[92],observation[93],"Katoxi",observation[95],observation[96])
    #print("Player X-Axis Y-Axis",observation[2],observation[3] ,"episode",i) SOSTO
    #print("------------")



   
     
      
 
    if(act ==0 ):
      
      # print("action 5",Action_list[action])
      new_observation,reward,done,info = env.step(5)
      
      act=1
      #print(new_observation)
    #print("Sto Else",observation[94],observation[95],observation[96])
    

    #CUSTOM ACTIONS
    action = agent.choose_action(observation) # from 1-4 which is index to action list

    while((observation[0]<0.65)  and (Action_list[action]==12)): #Den kanei shout ektos periohis
      action = agent.choose_action(observation)
     
      #print("Player Position:",observation[0],observation[1])
      #print("Player Direction:",observation[2],observation[3])
      #print("Ball Position:",observation[4],observation[5],observation[6])
      #print("Ball Direction:",observation[7],observation[8],observation[9])

    if(shout==0):   #ama kanei shout na min kanei tipota meta 
      new_observation,reward,done,info = env.step(Action_list[action])
      
      if(Action_list[action]==12):
        #print("EKANE SHOUT")
        shout=1
    else:
      #print("MPIKE STO ELSE")
      new_observation,reward,done,info = env.step(0)
      action=0 #Ta parakato if den pianoun to Action_list[action]=12 alla gia Action_list[action]=4

   
    
    
    #CUSTOM REWARDS
    
    if(done ==1 and reward != 1): #if ball is out ,loses -2
      print("Ball is out reward:",reward)
      reward = reward -10
      print("ball is out -10","episode",i,"Ball Position",observation[4],observation[5],observation[6],"step=",steps)
    if(reward==1 and  done ==1): #if agent scores , wins +5
      print("goal","episode",i,"step=",steps)
      reward = 10

    if((observation[0]<0.5)  and (Action_list[action]==12)): #an shoutarei prin th megali perioxh -2
      
      reward= reward -200
      done=1
      print("shout ektos periohis","episode",i,"step=",steps)
      
    if((observation[0]>0.6) and (Action_list[action]==12)): #an shoutarei mesa ti megali periohi +0.1
      #reward= reward +0.1
      print("shout entos periohis Ball Position",observation[4],observation[5],observation[6],"episode",i,"step=",steps)
      
    
    reward = reward - ( math.sqrt( ((0.935 - observation[4])**2) + (0 -observation[5])**2 ) *0.2) #oso pio makria einai toso perissotero xanei
    #print("Den exo mpala",Action_list[action])
    #print("DEN EXO MPALA",Action_list[action],action)

    #custom reward here
 
    
   
    score= +reward

    #for prints
    eps_rew+=reward
    #all_prints.print_who_scored(reward)
    

    agent.store_transition(observation,action,reward,new_observation,done)
    agent.learn()
    observation = new_observation

    scores.append(score)
    ep_history.append(agent.epsilon)

    avg_score= np.mean(scores)


    steps=steps+1
    
#---- BE CAREFUL OF THE WHILE !!! HERE IS EPIDOSE ENDING--------
  #print("Reward",eps_rew,"Episode",i,"Steps" , steps)
  step_list.append(steps)
  steps=0

  val = info.values()
  list_val=list(val)
  score_list.append(list_val)
  
  #terminate if 500 episodes are correct 
  if(eps_rew == 1 ):
    terminal= terminal +1
    if(terminal == 500):
      print("500 Episodes with goal")
      break
  else:
      terminal =0 
  episode = episode +1 
  

  rew_list.append(eps_rew)

# PRINTS
  if (i % 10)== 0 :
      print("---Avg reward last:", np.mean(rew_list[-10:]),"Avg score last",np.mean(score_list[-10:]),"Avg steps",np.mean(step_list[-10:]),"episode=",i,"---")
      #print(score_list)

  if (((i % 1000)== 0) and i!=0) :
      all_prints.score_graph(score_list[-1000:],1000)# graph the last 1000 episodes
  if(((i%50)==0) and i!=0):
    all_prints.rew_graph(rew_list[-i:],i)
     
  
  #EPISODE PRINTS
  #all_prints.printstats(i,rew_list,eps_rew,agent.epsilon)
  
  eps_rew=0



print("Avg score last:", np.mean(rew_list[-10:]),"Avg score",np.mean(score_list),"Avg steps",np.mean(step_list[-10:]),"episode=",i)
all_prints.score_graph(score_list[-1000:],1000)# graph the last 1000 episodes
      
#all_prints.score_graph(score_list,i+1)#i = num_of_eps
#print("\n ")
#all_prints.rew_graph(rew_list,i+1)
# Out:
# shout entos periohis Ball Position 0.70441735 -0.049457338 0.111903585 episode 0 step= 111
# goal episode 0 step= 121
# ---Avg reward last: -3.3340761624288326 Avg score last 1.0 Avg steps 122.0 episode= 0 ---
# shout entos periohis Ball Position 0.6833924 -0.07706233 0.11079106 episode 1 step= 101
# goal episode 1 step= 113
# shout entos periohis Ball Position 0.65858084 0.06412372 0.111187845 episode 2 step= 99
# goal episode 2 step= 111
# shout entos periohis Ball Position 0.66518456 -0.049789168 0.123970635 episode 3 step= 99
# goal episode 3 step= 112
# shout entos periohis Ball Position 0.66955155 0.024661383 0.11742989 episode 4 step= 103
# goal episode 4 step= 114
# shout entos periohis Ball Position 0.7168726 -0.018528247 0.11312432 episode 5 step= 113
# goal episode 5 step= 121
# shout entos periohis Ball Position 0.65797853 -0.043842133 0.11137213 episode 6 step= 103
# Ball is out reward: 0.0
# ball is out -10 episode 6 Ball Position 1.0111152 -0.064801626 0.13689166 step= 115
# shout entos periohis Ball Position 0.7128497 -0.12102778 0.11237263 episode 7 step= 106
# Ball is out reward: 0.0
# ball is out -10 episode 7 Ball Position 1.015406 -0.07264494 0.2627259 step= 117
# shout entos periohis Ball Position 0.73870945 -0.115334176 0.1288345 episode 8 step= 116
# Ball is out reward: 0.0
# ball is out -10 episode 8 Ball Position 1.0111723 -0.047020044 0.12360607 step= 125
# shout entos periohis Ball Position 0.7378811 -0.012110837 0.13237862 episode 9 step= 118
# goal episode 9 step= 126
# shout entos periohis Ball Position 0.7243983 -0.031306572 0.10960257 episode 10 step= 120
# goal episode 10 step= 131
# ---Avg reward last: -9.07792593593868 Avg score last 0.7 Avg steps 119.5 episode= 10 ---
# shout entos periohis Ball Position 0.79849625 0.007297739 0.11108017 episode 11 step= 129
# goal episode 11 step= 137
# shout entos periohis Ball Position 0.8040157 -0.12258872 0.12135806 episode 12 step= 124
# Ball is out reward: 0.0
# ball is out -10 episode 12 Ball Position 1.0088497 -0.087262906 0.7045204 step= 133
# shout entos periohis Ball Position 0.65956706 0.011763007 0.11434474 episode 13 step= 101
# Ball is out reward: 0.0
# ball is out -10 episode 13 Ball Position 1.0051333 -0.048064325 0.10259758 step= 113
# shout entos periohis Ball Position 0.6647479 -0.035546783 0.11181474 episode 14 step= 106
# Ball is out reward: 0.0
# ball is out -10 episode 14 Ball Position 1.0084875 -0.08763301 0.47726956 step= 118
# shout entos periohis Ball Position 0.7597113 0.0047597475 0.11176626 episode 15 step= 119
# goal episode 15 step= 129
# shout entos periohis Ball Position 0.6630611 0.023899421 0.11103843 episode 16 step= 101
# goal episode 16 step= 113
# shout entos periohis Ball Position 0.6694678 0.008285445 0.11526029 episode 17 step= 109
# goal episode 17 step= 118
# shout entos periohis Ball Position 0.6606602 -0.0075959875 0.11304326 episode 18 step= 100
# Ball is out reward: 0.0
# ball is out -10 episode 18 Ball Position 0.98782724 -0.045846377 0.30055943 step= 113
# shout entos periohis Ball Position 0.6645998 -0.04879621 0.11245175 episode 19 step= 104
# goal episode 19 step= 114
# shout entos periohis Ball Position 0.65621537 -0.058332283 0.13284038 episode 20 step= 106
# goal episode 20 step= 117
# ---Avg reward last: -11.188901895811274 Avg score last 0.6 Avg steps 121.5 episode= 20 ---
# shout entos periohis Ball Position 0.7240383 0.034663647 0.110991016 episode 21 step= 119
# goal episode 21 step= 130
# shout entos periohis Ball Position 0.8091341 -0.008348135 0.11109989 episode 22 step= 128
# Ball is out reward: 0.0
# ball is out -10 episode 22 Ball Position 1.0097588 0.28697446 0.13269022 step= 203
# shout entos periohis Ball Position 0.66722727 0.026275065 0.11301048 episode 23 step= 109
# goal episode 23 step= 118
# shout entos periohis Ball Position 0.66525465 -0.058552705 0.11644659 episode 24 step= 104
# goal episode 24 step= 115
# shout entos periohis Ball Position 0.66560614 0.0072203707 0.11264446 episode 25 step= 95
# goal episode 25 step= 104
# shout entos periohis Ball Position 0.66030735 0.038603343 0.1065888 episode 26 step= 98
# goal episode 26 step= 109
# shout entos periohis Ball Position 0.66475576 -0.0033365646 0.10895328 episode 27 step= 107
# goal episode 27 step= 117
# shout entos periohis Ball Position 0.66287637 0.0015600794 0.11649062 episode 28 step= 106
# goal episode 28 step= 117
# shout entos periohis Ball Position 0.6612143 -0.004911056 0.109998256 episode 29 step= 96
# goal episode 29 step= 108
# shout entos periohis Ball Position 0.6641985 -0.038020626 0.11023361 episode 30 step= 102
# Ball is out reward: 0.0
# ball is out -10 episode 30 Ball Position 1.0102658 -0.049988415 1.0023865 step= 112
# ---Avg reward last: -7.35776139254764 Avg score last 0.8 Avg steps 124.3 episode= 30 ---
# shout entos periohis Ball Position 0.6584554 -0.07642956 0.11903 episode 31 step= 107
# Ball is out reward: 0.0
# ball is out -10 episode 31 Ball Position 0.9884362 -0.07198778 1.6047637 step= 118
# shout entos periohis Ball Position 0.6593037 0.03007005 0.107833326 episode 32 step= 106
# goal episode 32 step= 117
# shout entos periohis Ball Position 0.6602239 -0.032008503 0.110663444 episode 33 step= 103
# goal episode 33 step= 115
# shout entos periohis Ball Position 0.66486585 -0.025323 0.12555 episode 34 step= 103
# goal episode 34 step= 113
# shout entos periohis Ball Position 0.6679558 -0.037235476 0.11324948 episode 35 step= 105
# goal episode 35 step= 116
# shout entos periohis Ball Position 0.66117007 -0.04434711 0.11293444 episode 36 step= 101
# goal episode 36 step= 114
# shout entos periohis Ball Position 0.7802596 -0.037647195 0.10877904 episode 37 step= 118
# Ball is out reward: 0.0
# ball is out -10 episode 37 Ball Position 1.00486 -0.047864176 0.1212714 step= 126
# shout entos periohis Ball Position 0.68479323 -0.011818419 0.1216781 episode 38 step= 105
# Ball is out reward: 0.0
# ball is out -10 episode 38 Ball Position 1.0087237 -0.045898132 0.19593251 step= 114
# shout entos periohis Ball Position 0.6602261 -0.046752308 0.12584254 episode 39 step= 109
# goal episode 39 step= 121
# shout entos periohis Ball Position 0.6665098 -0.049918275 0.10815047 episode 40 step= 107
# Ball is out reward: 0.0
# ball is out -10 episode 40 Ball Position 1.0122696 -0.048021656 0.09365328 step= 118
# ---Avg reward last: -11.07517677906513 Avg score last 0.6 Avg steps 118.2 episode= 40 ---
# shout entos periohis Ball Position 0.65761805 0.0018939009 0.11295118 episode 41 step= 95
# goal episode 41 step= 106
# shout entos periohis Ball Position 0.66191804 -0.08227605 0.111052334 episode 42 step= 100
# Ball is out reward: 0.0
# ball is out -10 episode 42 Ball Position 0.99449754 -0.0643593 0.12928306 step= 111
# shout entos periohis Ball Position 0.6638086 -0.043285266 0.11391541 episode 43 step= 98
# goal episode 43 step= 109
# shout entos periohis Ball Position 0.66778564 0.011451927 0.12231437 episode 44 step= 110
# Ball is out reward: 0.0
# ball is out -10 episode 44 Ball Position 1.0174574 -0.049143612 0.12505962 step= 120
# shout entos periohis Ball Position 0.658714 0.0046001473 0.1166248 episode 45 step= 110
# goal episode 45 step= 121
# shout entos periohis Ball Position 0.7316514 -0.021343267 0.11534083 episode 46 step= 115
# goal episode 46 step= 123
# shout entos periohis Ball Position 0.695908 -0.004442083 0.10940301 episode 47 step= 104
# Ball is out reward: 0.0
# ball is out -10 episode 47 Ball Position 1.0176963 -0.058444653 0.2747625 step= 115
# shout entos periohis Ball Position 0.6628537 -0.07454171 0.13095975 episode 48 step= 104
# goal episode 48 step= 115
# shout entos periohis Ball Position 0.66672844 0.0139014255 0.11155207 episode 49 step= 99
# goal episode 49 step= 109
# shout entos periohis Ball Position 0.66533804 -0.12209144 0.11436787 episode 50 step= 110
# goal episode 50 step= 122
# ---Avg reward last: -8.912492352493022 Avg score last 0.7 Avg steps 116.1 episode= 50 ---
# shout entos periohis Ball Position 0.6588471 0.017798923 0.1107552 episode 51 step= 105
# goal episode 51 step= 117
# shout entos periohis Ball Position 0.6629088 -0.038028806 0.121074975 episode 52 step= 105
# goal episode 52 step= 116
# shout entos periohis Ball Position 0.66190404 0.0025768606 0.11250414 episode 53 step= 107
# Ball is out reward: 0.0
# ball is out -10 episode 53 Ball Position 1.0135602 -0.054788526 0.40580496 step= 118
# shout entos periohis Ball Position 0.67170954 0.003170103 0.11671059 episode 54 step= 105
# Ball is out reward: 0.0
# ball is out -10 episode 54 Ball Position 1.008473 -0.05746499 0.13337119 step= 116
# shout entos periohis Ball Position 0.6632835 -0.07108528 0.12448485 episode 55 step= 104
# goal episode 55 step= 114
# shout entos periohis Ball Position 0.6716914 -0.07394021 0.111734465 episode 56 step= 106
# goal episode 56 step= 115
# shout entos periohis Ball Position 0.66470003 -0.06277035 0.11105834 episode 57 step= 104
# Ball is out reward: 0.0
# ball is out -10 episode 57 Ball Position 0.9968794 -0.053347778 0.21436772 step= 115
# shout entos periohis Ball Position 0.6653459 -0.041282557 0.11257458 episode 58 step= 101
# goal episode 58 step= 113
# shout entos periohis Ball Position 0.66426665 0.0018015362 0.11129312 episode 59 step= 103
# goal episode 59 step= 114
# shout entos periohis Ball Position 0.665756 -0.07308293 0.122971624 episode 60 step= 103
# goal episode 60 step= 113
# ---Avg reward last: -9.11270336660481 Avg score last 0.7 Avg steps 116.1 episode= 60 ---
# shout entos periohis Ball Position 0.7209548 -0.009641377 0.12329237 episode 61 step= 114
# Ball is out reward: 0.0
# ball is out -10 episode 61 Ball Position 1.0099001 -0.2873682 0.13122307 step= 160
# shout entos periohis Ball Position 0.6678113 -0.002072249 0.119118854 episode 62 step= 101
# Ball is out reward: 0.0
# ball is out -10 episode 62 Ball Position 0.9964911 0.05289982 0.109091826 step= 112
# shout entos periohis Ball Position 0.6624654 -0.022439538 0.12551858 episode 63 step= 111
# goal episode 63 step= 121
# shout entos periohis Ball Position 0.6642619 0.0003095993 0.113948934 episode 64 step= 108
# Ball is out reward: 0.0
# ball is out -10 episode 64 Ball Position 1.0085741 0.054174412 0.160568 step= 120
# shout entos periohis Ball Position 0.6609975 -0.027579078 0.11098851 episode 65 step= 106
# Ball is out reward: 0.0
# ball is out -10 episode 65 Ball Position 1.0198052 -0.049810562 0.18766499 step= 120
# shout entos periohis Ball Position 0.6608876 0.0032834662 0.11112233 episode 66 step= 99
# goal episode 66 step= 110
# shout entos periohis Ball Position 0.6666206 -0.00123115 0.11201331 episode 67 step= 107
# goal episode 67 step= 117
# shout entos periohis Ball Position 0.6619271 -0.039614566 0.1251804 episode 68 step= 97
# goal episode 68 step= 110
# shout entos periohis Ball Position 0.74054277 -0.017583659 0.11668964 episode 69 step= 117
# goal episode 69 step= 124
# shout entos periohis Ball Position 0.66490597 -0.09023612 0.123271964 episode 70 step= 101
# goal episode 70 step= 112
# ---Avg reward last: -11.293586789515016 Avg score last 0.6 Avg steps 121.6 episode= 70 ---
# shout entos periohis Ball Position 0.6821612 -0.010881569 0.111824736 episode 71 step= 107
# goal episode 71 step= 117
# shout entos periohis Ball Position 0.65638673 0.0001889265 0.11530856 episode 72 step= 104
# goal episode 72 step= 114
# shout entos periohis Ball Position 0.66674757 -0.05734945 0.112171985 episode 73 step= 93
# goal episode 73 step= 105
# shout entos periohis Ball Position 0.67565745 0.0003060008 0.11647757 episode 74 step= 113
# goal episode 74 step= 122
# shout entos periohis Ball Position 0.72027457 -0.011198458 0.10997266 episode 75 step= 114
# goal episode 75 step= 123
# shout entos periohis Ball Position 0.6660272 0.003001855 0.11988512 episode 76 step= 106
# goal episode 76 step= 115
# shout entos periohis Ball Position 0.7207095 -0.009238976 0.1125821 episode 77 step= 119
# goal episode 77 step= 128
# shout entos periohis Ball Position 0.6902035 -0.008311895 0.1160916 episode 78 step= 110
# Ball is out reward: 0.0
# ball is out -10 episode 78 Ball Position 1.0109596 -0.39185286 0.13209333 step= 179
# shout entos periohis Ball Position 0.6929754 -0.010822995 0.11458621 episode 79 step= 114
# goal episode 79 step= 122
# shout entos periohis Ball Position 0.7819984 -0.034283612 0.11390498 episode 80 step= 106
# Ball is out reward: 0.0
# ball is out -10 episode 80 Ball Position 1.0051018 -0.062065035 1.2499359 step= 114
# ---Avg reward last: -7.45494029291762 Avg score last 0.8 Avg steps 124.9 episode= 80 ---
# shout entos periohis Ball Position 0.6582923 0.010912316 0.11707162 episode 81 step= 102
# goal episode 81 step= 113
# shout entos periohis Ball Position 0.658115 -0.033846382 0.11298431 episode 82 step= 112
# goal episode 82 step= 124
# shout entos periohis Ball Position 0.66639465 -0.021514807 0.11154464 episode 83 step= 109
# Ball is out reward: 0.0
# ball is out -10 episode 83 Ball Position 1.0128673 -0.046777803 1.2755606 step= 120
# shout entos periohis Ball Position 0.6674159 -0.020746922 0.11172668 episode 84 step= 102
# goal episode 84 step= 111
# shout entos periohis Ball Position 0.66892076 -0.007503911 0.120744795 episode 85 step= 102
# goal episode 85 step= 112
# shout entos periohis Ball Position 0.65623534 -0.075822525 0.11989668 episode 86 step= 102
# Ball is out reward: 0.0
# ball is out -10 episode 86 Ball Position 1.0015782 -0.09591794 1.5915619 step= 114
# shout entos periohis Ball Position 0.66429365 0.004486269 0.1166711 episode 87 step= 108
# goal episode 87 step= 118
# shout entos periohis Ball Position 0.6613358 0.008765493 0.10958948 episode 88 step= 110
# goal episode 88 step= 123
# shout entos periohis Ball Position 0.657351 -0.0008221117 0.13154945 episode 89 step= 103
# goal episode 89 step= 114
# shout entos periohis Ball Position 0.6624172 -0.027283646 0.11175225 episode 90 step= 97
# Ball is out reward: 0.0
# ball is out -10 episode 90 Ball Position 0.9865968 -0.050431132 0.14980054 step= 108
# ---Avg reward last: -9.115706024964155 Avg score last 0.7 Avg steps 116.7 episode= 90 ---
# shout entos periohis Ball Position 0.66787755 -0.003466707 0.11248885 episode 91 step= 106
# goal episode 91 step= 116
# shout entos periohis Ball Position 0.66271955 0.01148159 0.11103295 episode 92 step= 103
# Ball is out reward: 0.0
# ball is out -10 episode 92 Ball Position 0.98795086 0.051359463 0.5131091 step= 115
# shout entos periohis Ball Position 0.7109768 -0.008270396 0.107018664 episode 93 step= 105
# goal episode 93 step= 113
# shout entos periohis Ball Position 0.6673888 -0.058301773 0.11506597 episode 94 step= 110
# goal episode 94 step= 121
# shout entos periohis Ball Position 0.6628994 -0.060322747 0.1119958 episode 95 step= 103
# goal episode 95 step= 115
# shout entos periohis Ball Position 0.66925496 -0.016723868 0.1278413 episode 96 step= 99
# goal episode 96 step= 111
# shout entos periohis Ball Position 0.69357485 -0.012629336 0.11023205 episode 97 step= 114
# Ball is out reward: 0.0
# ball is out -10 episode 97 Ball Position 1.0136849 -0.053044494 0.6922182 step= 124
# shout entos periohis Ball Position 0.66492385 -0.07208839 0.11351674 episode 98 step= 98
# goal episode 98 step= 107
# shout entos periohis Ball Position 0.73103076 -0.012042457 0.11200108 episode 99 step= 112
# goal episode 99 step= 119
# shout entos periohis Ball Position 0.6633971 0.0031146875 0.108428165 episode 100 step= 103
# goal episode 100 step= 113
# ---Avg reward last: -7.032435729104668 Avg score last 0.8 Avg steps 116.4 episode= 100 ---
# shout entos periohis Ball Position 0.65877646 -0.00339693 0.10956262 episode 101 step= 100
# goal episode 101 step= 111
# shout entos periohis Ball Position 0.66224957 -0.046256818 0.11150101 episode 102 step= 100
# goal episode 102 step= 109
# shout entos periohis Ball Position 0.66258585 -0.039781064 0.11809789 episode 103 step= 107
# Ball is out reward: 0.0
# ball is out -10 episode 103 Ball Position 1.0179467 -0.0548215 0.13005628 step= 119
# shout entos periohis Ball Position 0.6744489 0.023890816 0.12104122 episode 104 step= 107
# Ball is out reward: 0.0
# ball is out -10 episode 104 Ball Position 1.0109209 -0.046954762 0.1093871 step= 119
# shout entos periohis Ball Position 0.6622918 0.026920239 0.11815599 episode 105 step= 108
# goal episode 105 step= 120
# shout entos periohis Ball Position 0.66203743 -0.012001562 0.11103217 episode 106 step= 107
# goal episode 106 step= 118
# shout entos periohis Ball Position 0.6643924 -0.042822935 0.11346265 episode 107 step= 108
# Ball is out reward: 0.0
# ball is out -10 episode 107 Ball Position 1.0079516 -0.051797114 1.2181909 step= 120
# shout entos periohis Ball Position 0.6681379 -0.018818079 0.11752418 episode 108 step= 101
# Ball is out reward: 0.0
# ball is out -10 episode 108 Ball Position 1.0156803 0.06041864 0.11726582 step= 113
# shout entos periohis Ball Position 0.6651436 0.022127425 0.12542643 episode 109 step= 104
# goal episode 109 step= 115
# shout entos periohis Ball Position 0.6606431 -0.09399368 0.116710715 episode 110 step= 99
# goal episode 110 step= 110
# ---Avg reward last: -11.025196134704556 Avg score last 0.6 Avg steps 116.4 episode= 110 ---
# shout entos periohis Ball Position 0.66035837 -0.029174244 0.1167579 episode 111 step= 89
# goal episode 111 step= 99
# shout entos periohis Ball Position 0.6793784 0.024305755 0.12019603 episode 112 step= 111
# Ball is out reward: 0.0
# ball is out -10 episode 112 Ball Position 0.9963789 -0.0479018 0.15888578 step= 122
# shout entos periohis Ball Position 0.66256577 -0.00846228 0.11948788 episode 113 step= 105
# goal episode 113 step= 116
# shout entos periohis Ball Position 0.75241244 0.020471152 0.11446643 episode 114 step= 124
# goal episode 114 step= 131
# shout entos periohis Ball Position 0.6607906 0.056545466 0.12850429 episode 115 step= 102
# goal episode 115 step= 112
# shout entos periohis Ball Position 0.6656936 0.0063940207 0.10825017 episode 116 step= 103
# goal episode 116 step= 112
# shout entos periohis Ball Position 0.71784127 0.018661518 0.11735029 episode 117 step= 107
# goal episode 117 step= 115
# shout entos periohis Ball Position 0.65917057 -0.0035313363 0.11066119 episode 118 step= 106
# goal episode 118 step= 118
# shout entos periohis Ball Position 0.66226524 -0.08032821 0.11446462 episode 119 step= 93
# Ball is out reward: 0.0
# ball is out -10 episode 119 Ball Position 0.9899668 -0.04734896 0.7621981 step= 102
# shout entos periohis Ball Position 0.6653635 0.042822085 0.11142512 episode 120 step= 109
# goal episode 120 step= 119
# ---Avg reward last: -6.953430230927215 Avg score last 0.8 Avg steps 115.6 episode= 120 ---
# shout entos periohis Ball Position 0.6641178 0.04641957 0.1125413 episode 121 step= 98
# goal episode 121 step= 107
# shout entos periohis Ball Position 0.65945655 0.06533299 0.118995406 episode 122 step= 106
# goal episode 122 step= 118
# shout entos periohis Ball Position 0.66296417 -0.02532111 0.11253814 episode 123 step= 102
# goal episode 123 step= 111
# shout entos periohis Ball Position 0.6639762 -0.062151644 0.12584057 episode 124 step= 96
# goal episode 124 step= 107
# shout entos periohis Ball Position 0.66410756 0.014452136 0.10916961 episode 125 step= 103
# goal episode 125 step= 115
# shout entos periohis Ball Position 0.66203856 0.07403817 0.11137167 episode 126 step= 98
# Ball is out reward: 0.0
# ball is out -10 episode 126 Ball Position 0.9928739 0.05347704 1.5358871 step= 109
# shout entos periohis Ball Position 0.65960205 -0.049777385 0.111138545 episode 127 step= 109
# goal episode 127 step= 119
# shout entos periohis Ball Position 0.6585575 -0.008348381 0.13043898 episode 128 step= 103
# goal episode 128 step= 113
# shout entos periohis Ball Position 0.6639119 -0.044952963 0.11150336 episode 129 step= 106
# Ball is out reward: 0.0
# ball is out -10 episode 129 Ball Position 1.0099461 0.1501269 0.1274114 step= 185
# shout entos periohis Ball Position 0.6615727 0.16117515 0.1114246 episode 130 step= 101
# Ball is out reward: 0.0
# ball is out -10 episode 130 Ball Position 0.9943441 0.08656136 1.0080917 step= 113
# ---Avg reward last: -9.090359510148868 Avg score last 0.7 Avg steps 120.7 episode= 130 ---
# shout entos periohis Ball Position 0.66263485 0.03854941 0.110650286 episode 131 step= 106
# goal episode 131 step= 116
# shout entos periohis Ball Position 0.6604906 0.08579418 0.111063905 episode 132 step= 102
# Ball is out reward: 0.0
# ball is out -10 episode 132 Ball Position 1.0031735 0.06506218 0.4535996 step= 113
# shout entos periohis Ball Position 0.6644212 -0.021027263 0.12356107 episode 133 step= 103
# goal episode 133 step= 113
# shout entos periohis Ball Position 0.6613636 -0.008987688 0.11133469 episode 134 step= 98
# Ball is out reward: 0.0
# ball is out -10 episode 134 Ball Position 0.99890465 0.04896454 0.8684062 step= 111
# shout entos periohis Ball Position 0.6641015 0.043861352 0.10826184 episode 135 step= 98
# goal episode 135 step= 110
# shout entos periohis Ball Position 0.6610254 -0.051664837 0.108948134 episode 136 step= 97
# goal episode 136 step= 108
# shout entos periohis Ball Position 0.65778977 -0.034594283 0.10894869 episode 137 step= 104
# goal episode 137 step= 115
# shout entos periohis Ball Position 0.66540366 -0.074499935 0.11101964 episode 138 step= 102
# goal episode 138 step= 112
# shout entos periohis Ball Position 0.66639906 -0.011406094 0.12131195 episode 139 step= 101
# Ball is out reward: 0.0
# ball is out -10 episode 139 Ball Position 1.0139045 0.060851302 0.10851586 step= 115
# shout entos periohis Ball Position 0.661571 0.036907367 0.11116171 episode 140 step= 107
# goal episode 140 step= 118
# ---Avg reward last: -8.871720336458512 Avg score last 0.7 Avg steps 114.1 episode= 140 ---
# shout entos periohis Ball Position 0.65999424 -0.063077286 0.113081545 episode 141 step= 104
# goal episode 141 step= 114
# shout entos periohis Ball Position 0.6643397 0.002280699 0.11362992 episode 142 step= 104
# Ball is out reward: 0.0
# ball is out -10 episode 142 Ball Position 1.0109464 -0.057307288 0.5942086 step= 116
# shout entos periohis Ball Position 0.6622862 0.014337937 0.1107394 episode 143 step= 109
# goal episode 143 step= 120
# shout entos periohis Ball Position 0.6601035 -0.026156466 0.1083529 episode 144 step= 104
# goal episode 144 step= 114
# shout entos periohis Ball Position 0.6592126 0.008691766 0.11574191 episode 145 step= 96
# goal episode 145 step= 109
# shout entos periohis Ball Position 0.6572518 0.06882051 0.11296745 episode 146 step= 93
# goal episode 146 step= 106
# shout entos periohis Ball Position 0.66244113 -0.011648731 0.11071231 episode 147 step= 106
# goal episode 147 step= 119
# shout entos periohis Ball Position 0.66174155 0.023866683 0.12967058 episode 148 step= 98
# goal episode 148 step= 108
# shout entos periohis Ball Position 0.6614861 0.045168478 0.107683256 episode 149 step= 109
# goal episode 149 step= 120
# shout entos periohis Ball Position 0.66265655 0.017299399 0.11052156 episode 150 step= 101
# goal episode 150 step= 113
# ---Avg reward last: -4.83306695726016 Avg score last 0.9 Avg steps 114.9 episode= 150 ---
# shout entos periohis Ball Position 0.6625294 -0.1256888 0.11029165 episode 151 step= 110
# Ball is out reward: 0.0
# ball is out -10 episode 151 Ball Position 0.9899702 -0.09252973 0.59212977 step= 124
# shout entos periohis Ball Position 0.664283 0.0005224757 0.124991335 episode 152 step= 107
# goal episode 152 step= 119
# shout entos periohis Ball Position 0.6618177 0.042194184 0.119609766 episode 153 step= 95
# goal episode 153 step= 105
# shout entos periohis Ball Position 0.6664657 -0.02490012 0.112701766 episode 154 step= 101
# goal episode 154 step= 111
# shout entos periohis Ball Position 0.66191816 0.00368864 0.11150116 episode 155 step= 100
# goal episode 155 step= 112
# shout entos periohis Ball Position 0.66399425 0.031100426 0.11231046 episode 156 step= 104
# goal episode 156 step= 114
# shout entos periohis Ball Position 0.6619772 -0.0069401767 0.11466932 episode 157 step= 109
# goal episode 157 step= 119
# shout entos periohis Ball Position 0.6621257 -0.05059108 0.10695263 episode 158 step= 107
# goal episode 158 step= 117
# shout entos periohis Ball Position 0.6567101 0.020728579 0.12130624 episode 159 step= 104
# goal episode 159 step= 117
# shout entos periohis Ball Position 0.6576512 0.047428306 0.12472808 episode 160 step= 110
# Ball is out reward: 0.0
# ball is out -10 episode 160 Ball Position 0.9893485 0.049614646 0.18938105 step= 122
# ---Avg reward last: -7.1961021532742775 Avg score last 0.8 Avg steps 117.0 episode= 160 ---
# shout entos periohis Ball Position 0.6634128 -0.028591804 0.13112764 episode 161 step= 104
# Ball is out reward: 0.0
# ball is out -10 episode 161 Ball Position 1.0125655 -0.061306216 0.21963601 step= 115
# shout entos periohis Ball Position 0.6615293 -0.05474562 0.11066117 episode 162 step= 104
# Ball is out reward: 0.0
# ball is out -10 episode 162 Ball Position 1.0147588 -0.04981667 0.13465182 step= 114
# shout entos periohis Ball Position 0.66561574 -0.08216746 0.118498325 episode 163 step= 103
# goal episode 163 step= 113
# shout entos periohis Ball Position 0.6613668 0.007849207 0.10981452 episode 164 step= 97
# Ball is out reward: 0.0
# ball is out -10 episode 164 Ball Position 1.0058452 0.053092465 0.33261812 step= 109
# shout entos periohis Ball Position 0.66694725 -0.037767418 0.11107271 episode 165 step= 107
# goal episode 165 step= 116
# shout entos periohis Ball Position 0.6640794 0.009519773 0.108129166 episode 166 step= 106
# goal episode 166 step= 117
# shout entos periohis Ball Position 0.66115475 0.016775323 0.13046649 episode 167 step= 102
# goal episode 167 step= 113
# shout entos periohis Ball Position 0.6600685 -0.07041049 0.110581286 episode 168 step= 107
# Ball is out reward: 0.0
# ball is out -10 episode 168 Ball Position 1.0017408 -0.056238703 0.6933713 step= 117
# shout entos periohis Ball Position 0.65931433 0.017264452 0.110652015 episode 169 step= 107
# goal episode 169 step= 119
# shout entos periohis Ball Position 0.6618436 -0.018940078 0.11302938 episode 170 step= 105
# goal episode 170 step= 115
# ---Avg reward last: -10.943628765920584 Avg score last 0.6 Avg steps 115.8 episode= 170 ---
# shout entos periohis Ball Position 0.6623618 0.020889487 0.10842511 episode 171 step= 101
# goal episode 171 step= 114
# shout entos periohis Ball Position 0.66130966 -0.07353161 0.11323832 episode 172 step= 103
# goal episode 172 step= 115
# shout entos periohis Ball Position 0.6602869 0.07796211 0.11597887 episode 173 step= 100
# Ball is out reward: 0.0
# ball is out -10 episode 173 Ball Position 1.0070498 0.07472387 1.6178179 step= 111
# shout entos periohis Ball Position 0.6580206 0.020826856 0.11058888 episode 174 step= 109
# goal episode 174 step= 120
# shout entos periohis Ball Position 0.6668181 -0.092676885 0.11171175 episode 175 step= 98
# goal episode 175 step= 108
# shout entos periohis Ball Position 0.6608275 -0.07183042 0.12495363 episode 176 step= 104
# goal episode 176 step= 116
# shout entos periohis Ball Position 0.666632 0.016542226 0.112607345 episode 177 step= 109
# goal episode 177 step= 119
# shout entos periohis Ball Position 0.67111087 0.003101762 0.10920311 episode 178 step= 106
# goal episode 178 step= 116
# shout entos periohis Ball Position 0.66489464 0.020304874 0.116421774 episode 179 step= 100
# Ball is out reward: 0.0
# ball is out -10 episode 179 Ball Position 1.0005982 -0.04524543 0.7052013 step= 111
# shout entos periohis Ball Position 0.658192 -0.024557028 0.122405306 episode 180 step= 109
# goal episode 180 step= 120
# ---Avg reward last: -6.945839889235484 Avg score last 0.8 Avg steps 116.0 episode= 180 ---
# shout entos periohis Ball Position 0.65879554 0.072839305 0.11130259 episode 181 step= 105
# goal episode 181 step= 116
# shout entos periohis Ball Position 0.6720321 -0.010830114 0.111647695 episode 182 step= 100
# goal episode 182 step= 109
# shout entos periohis Ball Position 0.6602828 -0.023119688 0.108948246 episode 183 step= 91
# goal episode 183 step= 101
# shout entos periohis Ball Position 0.66360444 -0.1229408 0.11269623 episode 184 step= 102
# goal episode 184 step= 112
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-7cfee66e7e9d> in <module>()
#      67
#      68     while((observation[0]<0.65)  and (Action_list[action]==12)): #Den kanei shout ektos periohis
# ---> 69       action = agent.choose_action(observation)
#      70
#      71       #print("Player Position:",observation[0],observation[1])
#
# <ipython-input-41-99f4faf65f16> in choose_action(self, observation)
#      39
#      40       state =T.tensor([observation]).to(self.Q_eval.device) #turn observation to tensor and send it to device for computations
# ---> 41       action_list = self.Q_eval.forward(state) #returns the values of each action
#      42       action = T.argmax(action_list).item()
#      43       #print("exploit:",action)
#
# <ipython-input-32-25a3526c358c> in forward(self, state)
#      22
#      23     x=F.relu(self.fc1(state))
# ---> 24     x=F.relu(self.fc2(x))
#      25     x=F.relu(self.fc3(x))
#      26     actions=self.fc4(x)
#
# KeyboardInterrupt:

# %%
#plot step_list plt.plot(step_list)

# %%
class Custom_Rewards():
  #def __init__(self):
    #self.obs=obs    
    #self.action=action
    #self.reward =reward
  def custom_rew(self,obs,action,reward,new_obs):
    
    self.obs=obs
    self.action = action
    self.reward = reward
    self.new_obs=new_obs
    
    
#if the next action is shooting the ball, the reward will gain 0.2 point ||
#an exo ti mpala kai einai se apostasi x > 0.5 sto gipedo kai exei kanei shout einai kalo    
    if(self.obs[95] == 1 and self.obs[88] > 0.6 and self.action == 12):
      self.reward += 0.02
      #print("EKANE SHOUT MPROSTA APO TO KENTRO ,+0.1")
      return self.reward

    #An kanei shout piso apo to kentro na xanei ligo
    elif(self.obs[95]==1 and self.obs[88] < 0 and self.action == 12):
      self.reward -= 0.02
      #print("EKANE SHOUT PISO APO TO KENTRO, -0.05")
      return self.reward

# if we steal the ball, the reward will gain 0.05 points
    elif self.obs[96] == 1 and self.new_obs[95] == 1:  #obs[96] ball owner right team / obs[95] ball owner left team
        self.reward += 0.05
        #print("PHRE THN MPALA APO TON ANTIPALO , +0.05")
        return self.reward
#if we lose the ball, the reward will lose 0.05 points
    elif self.obs[95] == 1 and self.new_obs[96] == 1:
        self.reward -=0.02
        #print("PHRE THN MPALA O ANTIPALOS , -0.02")
        return self.reward
    else:
      return self.reward


#TODO: if active player far from the ball, the reward will lose by the moving distance

# %%
#print(score_list or reward_list)

# %%
"""print(observation)
new_observation,reward,done,info = env.step(4)
print(new_observation)"""

# %%
# gpu_info = !nvidia-smi
# gpu_info = '\n'.join(gpu_info)
# if gpu_info.find('failed') >= 0:
#   print('Not connected to a GPU')
# else:
#   print(gpu_info)

# %%
"""env = football_env.create_environment(env_name ='academy_single_goal_versus_lazy',render=False,representation='simple115')
observation =env.reset()
new_observation,reward,done,info = env.step(action)
val=info.values()
print(val)
list_val=list(val)
list_val"""
