# %%
#https://www.kaggle.com/piotrstanczyk/gfootball-template-bot  G-FOOTBALL TEMPLATE BOT
# Install:
# Kaggle environments.
#!git clone https://github.com/Kaggle/kaggle-environments.git
#!cd kaggle-environments && pip install .

# GFootball environment.
# !apt-get update -y
# !apt-get install -y libsdl2-gfx-dev libsdl2-ttf-dev

# Make sure that the Branch in git clone and in wget call matches !!
# !git clone -b v6 https://github.com/Georgemouts/football.git #https://github.com/google-research/football.git  
# !mkdir -p football/third_party/gfootball_engine/lib

# !wget https://storage.googleapis.com/gfootball/prebuilt_gameplayfootball_v2.8.so -O football/third_party/gfootball_engine/lib/prebuilt_gameplayfootball.so
# !cd football && GFOOTBALL_USE_PREBUILT_SO=1 pip3 install .

# !pip install utils
#!pip install learning
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 252 kB in 2s (123 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsdl2-gfx-dev is already the newest version (1.0.4+dfsg-1).
# libsdl2-ttf-dev is already the newest version (2.0.14+dfsg1-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# fatal: destination path 'football' already exists and is not an empty directory.
# --2022-06-18 16:10:27--  https://storage.googleapis.com/gfootball/prebuilt_gameplayfootball_v2.8.so
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.196.128, 173.194.198.128, 173.194.192.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.196.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45403632 (43M) [application/octet-stream]
# Saving to: ‘football/third_party/gfootball_engine/lib/prebuilt_gameplayfootball.so’
#
# football/third_part 100%[===================>]  43.30M  75.9MB/s    in 0.6s
#
# 2022-06-18 16:10:28 (75.9 MB/s) - ‘football/third_party/gfootball_engine/lib/prebuilt_gameplayfootball.so’ saved [45403632/45403632]
#
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/football
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Requirement already satisfied: pygame>=1.9.6 in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (2.1.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (4.1.2.30)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (5.4.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (1.21.6)
# Requirement already satisfied: gym<=0.21.0 in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (0.17.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (1.1.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (0.37.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym<=0.21.0->gfootball==2.10.3) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym<=0.21.0->gfootball==2.10.3) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym<=0.21.0->gfootball==2.10.3) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym<=0.21.0->gfootball==2.10.3) (0.16.0)
# Building wheels for collected packages: gfootball
#   Building wheel for gfootball (setup.py) ... done
#   Created wheel for gfootball: filename=gfootball-2.10.3-cp37-cp37m-linux_x86_64.whl size=24050757 sha256=b92f1e82f27cd4d2760cba076bf4d05717d4ab54ae0c2115ede3ef818c758e22
#   Stored in directory: /tmp/pip-ephem-wheel-cache-h84q1o6k/wheels/bb/c2/92/82a23d0c207f5497a23f4316675eb1629e6be474bd2c3be61a
# Successfully built gfootball
# Installing collected packages: gfootball
#   Attempting uninstall: gfootball
#     Found existing installation: gfootball 2.10.3
#     Uninstalling gfootball-2.10.3:
#       Successfully uninstalled gfootball-2.10.3
# Successfully installed gfootball-2.10.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: utils in /usr/local/lib/python3.7/dist-packages (1.0.1)

# %%
#from gfootball.env.football_env import FootballEnv
#from kaggle_environments import make
from gfootball.env.config import Config
import gfootball.env as football_env

#import dqn libraries
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim 
import numpy as np
import pandas as pd
import itertools
import utils
import random
from collections import deque
import matplotlib.pyplot as plt
#from utils import plot_learning_curve
#import env 
import gym
import gfootball 
import math
import os
import utils
#from utils import plotLearning

#from dueling_dqn_torch import Agent

# %%
env = football_env.create_environment(env_name ='academy_empty_goal',render=False,representation='simple115v2')

new_observation,reward,done,info = env.step(5)
print(new_observation)
# Out:
# [ 0.         -0.          0.         -0.          1.0110294   0.
#  -0.          0.          0.02       -0.          0.11059734 -0.
#   0.         -0.00191829  1.          0.          0.        ]

# %%
class DeepQNetwork(nn.Module):
  def __init__(self,lr,input_dims,fc1_dims,fc2_dims,n_actions):
    super(DeepQNetwork,self).__init__()
   # self.lr=lr
    self.input_dims=input_dims
    self.fc1_dims=fc1_dims
    self.fc2_dims=fc2_dims
    
    self.n_actions=n_actions
    
    self.fc1=nn.Linear(*self.input_dims,self.fc1_dims) #pass list of observations as input
    self.fc2=nn.Linear(self.fc1_dims,self.fc2_dims)
    self.fc3=nn.Linear(self.fc2_dims,self.n_actions)
    #self.fc4=nn.Linear(self.fc3_dims,self.n_actions) #output number action

    self.optimizer = optim.Adam(self.parameters(),lr=lr)
    self.loss=nn.MSELoss()
    self.device =T.device('cuda:0' if T.cuda.is_available() else 'cpu' )
    self.to(self.device)

  def forward(self,state):
   
    x=F.relu(self.fc1(state))
    x=F.relu(self.fc2(x))
    actions=self.fc3(x)
    #x=F.relu(self.fc3(x))
    return actions

# %%
class Agent():
  def __init__(self,gamma,epsilon, lr , input_dims , batch_size ,n_actions, max_mem_size = 10000  , eps_end=0.01 , eps_dec = 5e-4):
    self.gamma=gamma
    self.epsilon =epsilon
    self.lr=lr
    self.eps_min=eps_end
    self.eps_dec=eps_dec
   
    self.action_space =[i for i in range(n_actions)]
    self.mem_size = max_mem_size
    self.batch_size = batch_size
    #self.n_actions=n_actions
    self.mem_cntr =0 # keep track of the position of first available memory 

    self.Q_eval = DeepQNetwork(self.lr,n_actions=n_actions,input_dims= input_dims, fc1_dims=128, fc2_dims=128)

    self.state_memory = np.zeros((self.mem_size,*input_dims),dtype =np.float32)
    self.new_state_memory= np.zeros((self.mem_size , *input_dims),dtype=np.float32)

    self.action_memory=np.zeros(self.mem_size , dtype=np.int32) #discrete actions 
    self.reward_memory=np.zeros(self.mem_size,dtype= np.float32)
    self.terminal_memory= np.zeros(self.mem_size,dtype=bool)


  def store_transition(self,state,action,reward,new_state , done ):
    index = self.mem_cntr% self.mem_size

    self.state_memory[index]= state
    self.new_state_memory[index]= new_state
    self.reward_memory[index]= reward
    self.action_memory[index]= action  #which action is taken 
    self.terminal_memory[index]= done

    self.mem_cntr +=1
    

  def choose_action(self,observation):
    if np.random.random()> self.epsilon:
      
      state =T.tensor([observation]).to(self.Q_eval.device) #turn observation to tensor and send it to device for computations
      action_list = self.Q_eval.forward(state) #returns the values of each action
      action = T.argmax(action_list).item()
      #print("exploit:",action)
    else:     #
      
      action = np.random.choice(self.action_space)
      #print("explore:",action)
    return action

  def learn(self):    #fill batch size then learn 
    if self.mem_cntr < self.batch_size :
     
      return
    
    
    self.Q_eval.optimizer.zero_grad()

    #calculate the position of max memory / extract subset of max memories
    max_mem =min(self.mem_cntr , self.mem_size)
    


    batch=np.random.choice(max_mem,self.batch_size,replace=False) #We dont keep selecting the same memories more than once
     
    #batch = np.random.permutation(max_mem)[:self.batch_size]
    #mem = np.array(exp_buffer)[perm_batch]

    #batch=np.random.choice(max_mem,self.batch_size,replace=False)
    batch_index = np.arange(self.batch_size , dtype=np.int32)

    state_batch=T.tensor(self.state_memory[batch]).to(self.Q_eval.device) #make numpy array a pytorch tensor
    new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
    reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
    terminal_batch= T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)

    action_batch = self.action_memory[batch] 
  
    q_eval = self.Q_eval.forward(state_batch)[batch_index,action_batch] #EXEI THEMA
    q_next = self.Q_eval.forward(new_state_batch)

    q_next[terminal_batch] = 0.0
    q_target = reward_batch +self.gamma * T.max(q_next,dim=1)[0] #max value of next state

    loss = self.Q_eval.loss(q_target,q_eval).to(self.Q_eval.device)
    loss.backward()
    self.Q_eval.optimizer.step()

    self.epsilon = self.epsilon - self.eps_dec if (self.epsilon > self.eps_min)  else self.eps_min

# %%
class All_prints():
  
  def __init___(self,step):
    self.step=step
    #self.RewBuffer = RewBuffer
    self.reward=reward

  def printstats(self,step,rew_list,eps_reward,epsilon):  #Kaleitai otan ginei done , diladi otan teleiosei ena paixnidi
    self.step=step
    self.rew_list=rew_list
    self.eps_reward=eps_reward
    self.epsilon=epsilon
    print("-->Episode:",i%3000 + 1,"\t","Episode Reward:",eps_reward,"\t Epsilon",agent.epsilon,"<--")
    #print("Step",step)
    print("lista apo rewards mexri tora" ,self.rew_list)
    print("Avg reward", np.mean(self.rew_list))
    print("---------------------------------------------------")

  def print_who_scored(self, reward):
    self.reward=reward
    if(self.reward==1):
      print("our team scored !!!")
    elif(self.reward ==-1):
      print("opponent team scored")
    
    
 
  def rew_graph(self,rew_list,num_of_eps):
      self.rew_list=rew_list
      
      self.num_of_eps=num_of_eps
      
      eps_list=list(range(1,self.num_of_eps+1))#pairnei to proto , den pairnei to teleytaio
      
      plt.plot(eps_list,self.rew_list)
      plt.xlabel('Episode')
      plt.ylabel('Rewards')
      plt.grid(True)
      plt.show()

  def step_graph(self,step_list,num_of_eps):
      self.step_list=step_list
      
      self.num_of_eps=num_of_eps
      
      eps_list=list(range(1,self.num_of_eps+1))#pairnei to proto , den pairnei to teleytaio
      
      plt.plot(eps_list,self.step_list)
      plt.xlabel('Episodes')
      plt.ylabel('Steps_to_score')
      plt.grid(True)
      plt.show()


  def score_graph(self,score_list,num_of_eps):
      self.score_list=score_list
      
      self.num_of_eps=num_of_eps
      
      eps_list=list(range(1,self.num_of_eps+1))#pairnei to proto , den pairnei to teleytaio
      
      plt.plot(eps_list,self.score_list)
      plt.xlabel('Episode')
      plt.ylabel('Score')
      plt.grid(True)
      plt.show()

# %%
env = football_env.create_environment(env_name ='academy_empty_goal',render=False,representation='simple115v2')  #List with the 115 states 


#CUSTOMIZE ACTION LIST AND OBSERVATIONS
Action_list=[4,5,6,12,13,14,15,17,18]
#print(env.action_space.n)
#Create Objects


agent = Agent(gamma=0.99,epsilon=1.0 ,batch_size = 64 ,lr=0.00115 ,input_dims= [17], n_actions = len(Action_list) )# batch = best 256
all_prints = All_prints()
#cus_rew =Custom_Rewards()

scores,ep_history =[],[]

steps=0
terminal =0 # an skorarei se pano apo enan arithmo paixnidion stamatao tin ekpaideysi 
episode =0
shout =0


num_of_eps = 3000
eps_rew=0
rew_list =[]
score_list = []
step_list =[]
goal_steps=[]


for i in range(num_of_eps) : 
  score =0 
  done=False 
  eps_rew=0
  observation =env.reset()
  #print("Pinakas apo observations",observation)
  act =0 #first action will be to move right 
  shout=0 #mporei na kanei shout 1 fora se kathe ep
  timer=0 # an klepsei tin mpala kai tin kratisei pano apo 4 steps stamata
  forward=0 #an perasei ton antipalo kai kanei sprint tin proti fora  einai +5
  checkpoint_reward=[1,1,1,1,1]
  steps=0
  while not done:

    #CUSTOMIZE ACTIONS HERE 
   
    
    #print("------------")
    #print("Ball X-Y-Z Axis",observation[88],observation[89],observation[90],"||","direct",observation[91],observation[92],observation[93],"Katoxi",observation[95],observation[96])
    #print("Player X-Axis Y-Axis",observation[2],observation[3] ,"episode",i) SOSTO
    #print("------------")

    #print(observation[0],observation[1],observation[2],observation[3],observation[4],observation[5])
    

   
     
      
 
    if(act ==0 ): # proti praksi ena bima deksia
      
      # print("action 5",Action_list[action])
      new_observation,reward,done,info = env.step(5)
      
      act=1
      #print(new_observation)
    #print("Sto Else",observation[94],observation[95],observation[96])
    

    #CUSTOM ACTIONS
    action = agent.choose_action(observation) # from 1-9s which is index to action list

    #while((observation[4]> observation[0] )  and (Action_list[action]==13 or Action_list[action]==15) and observation[14]==1): #den kanei sprint prin perasei ton paikti
     # action = agent.choose_action(observation)

    #while(observation[4] - observation[0] >0.2 and observation[4]-observation[0]>0 and (Action_list[action]==17 or Action_list[action]==18 )):
     # action = agent.choose_action(observation)

    while((observation[0] > observation[4] +0.08)  and (Action_list[action]==17 or Action_list[action]==18 )): # an ton perasei min kanei drible 
      action = agent.choose_action(observation)
    while((observation[0]<0.65)  and (Action_list[action]==12)): #Den kanei shout ektos periohis
      action = agent.choose_action(observation)
     
    #if(observation[0]>observation[4]+0.05  and observation [0] < 0.6):
      #print("perase kai sprint")
      #action = 4

      #print("Player Position:",observation[0],observation[1])
      #print("Player Direction:",observation[2],observation[3])
      #print("Ball Position:",observation[4],observation[5],observation[6])
      #print("Ball Direction:",observation[7],observation[8],observation[9])

    if(shout==0):   #ama kanei shout na min kanei tipota meta 
      new_observation,reward,done,info = env.step(Action_list[action])
      
      if(Action_list[action]==12):
        #print("EKANE SHOUT")
        shout=1
    else:
      #print("MPIKE STO ELSE")
      new_observation,reward,done,info = env.step(0)
      action=0 #Ta parakato if den pianoun to Action_list[action]=12 alla gia Action_list[action]=4

#CUSTOM REWARDS-------------------------------
    if(done ==1 and reward ==1): #if agent scores , wins +50
      print("goal","episode",i,"step=",steps)
      reward += 50 

   
    if(done ==1 and reward == 0): # an bgei i mpala apo ton antipalo einai -15 , a bgei apo ton paikti einai -5 
      if(shout ==1 ):
        reward = reward - 5
        print("Ball is out by player - 5")
      else:
        reward = reward -15 #12
        print("ball is out -15","episode",i,"Ball Position",observation[8],observation[9],observation[10],"step=",steps)
        terminal =0



      terminal= terminal +1
      goal_steps.append(steps)


    if(observation[16]==1 ):  # an klepsei tin mpala kai tin kratisei pano apo 4 steps stamata
      timer=timer+1
      if(timer <= 2 ):
        reward = reward - 30
      if (timer>2 and timer <  4 ):
        reward = reward - 2
      if (timer>4 and timer <6 ):
        reward = reward - 20
        print("klepsimo")
        done =1 
      if(timer >= 8):
        done=1
        reward = reward -20
        print("klepsimo")

    if(observation[8]< 0.0 ):  #An i mpala paei piso apo to kentro telos paixnidiou
      print("Mpala piso apo kentro")
      reward = reward-25
      done =1 

    #----------------
    #if(observation[14]== 0): #an den exo stin katoxi tin mpala einai -5
     # reward =reward-5
    #if(observation[14] == 1): # an exo tin katoxi na einai +2
     #reward =reward +5

    if ((observation[8] > observation[0] + 0.05) and (observation[9] - observation[1] <=0.03) or(observation[9] - observation[1] >=-0.03) ) and Action_list[action]==5:
      reward = reward +5
          

    if(observation[16]==1):
      reward = reward - 10

    if(observation[4] - observation[0] > 0.2 and Action_list[action]==5): # an einai makria o antipalos kai kano bima deksia +2
        reward =reward +2
    if(observation[4] - observation[0] > 0.2 and (Action_list[action] == 14 or Action_list[action] == 15 or Action_list[action] == 18 )): # an meinei akinitos  einai -2
        reward = reward - 5

    if((observation[0] > observation [4] +0.1) and (Action_list[action]==13)and (observation[14]==1)): #An peraso ton antipalo kai kano sprint tin proti fora +5
      print("perase ton antipalo kai sprint NO REWARD")
      #reward =reward + 10 
    #----------------

    if((observation[4]-observation[0]< 0.07)and (observation[4]-observation[0]> 0) and (Action_list[action]==17)):  # an kanei dirbble konta ston antipalo prin erthei se ayton +15 
      print("dribble prin ton antipalo")
      #reward = reward + 2



    if(((observation[0] > observation [4] + 0.08) and observation[14]== 1 ) and (observation [0]>-0.2 or observation[0]<0.2)):  # an perasei ton antipalo einai +5
      print("perase ton antipalo kanonika")
      reward = reward + 1
      if(forward ==0):
        forward =1
        reward = reward + 15
      #done =1
      #print(observation)
      
      """if((observation[0]>0.6) and (Action_list[action]==12)) : #an ton perasei kai mpei perioxi kai shoutarei einai + 10
        print("Shout entos periohis")
        reward = reward +15
      #if((observation[0] > observation [4] +0.1) and (Action_list[action]==13) and (sprint ==0)and (observation[14]==1)): # an ton perasei k kanei sprint +5
        #reward = reward + 8
      if((Action_list[action]==13) and (observation[14]==1)): # ton pernaei kai paei deksia 
        reward = reward + 8
      if((Action_list[action]==17) or (Action_list[action]==18) ): # an ton perasei kai kanei drible i stamatisei -20
        print("ton perase kai kanei drible h stamatisei", Action_list[action])
        reward = reward - 20"""

    
    if((observation[4] > observation[0]) and (Action_list[action]==13 or Action_list[action]==15) and observation[14]==1): # an einai apenanti o paiktis kai kano sprint -5
      print("PROSOXI lathos sprint")
      reward = reward - 5                                     #PROSOXI EDO

    if((observation[4] < observation[0]) and (Action_list[action]==13 or Action_list[action]==15) and observation[14]==1 and (observation[1]>-0.2 or observation[1]<0.2)):
       reward = reward + 2
       print("sprint afou exei perasei")
  

    if((observation[0]<0.65)  and (Action_list[action]==12)): #an shoutarei prin th megali perioxh -2
      reward= reward -200
      done=1
      print("shout ektos periohis","episode",i,"step=",steps)
      
    if((observation[0]>0.6) and (Action_list[action]==12) ): #an shoutarei mesa ti megali periohi +10
      reward= reward +10
      print("shout entos periohis Ball Position",observation[8],observation[9],observation[10],"episode",i,"step=",steps)
      
    

    
    reward = reward - ( math.sqrt( ((0.935 - observation[8])**2) + (0 -observation[9])**2 ) *0.3) #oso pio makria einai toso perissotero xanei

    #END OF CUSTOM REWARDS ----------------------------- 
 
    
   
    score+= reward/11

    #for prints
    
    #all_prints.print_who_scored(reward)
    

    agent.store_transition(observation,action,reward,new_observation,done)
    agent.learn()
    observation = new_observation

    scores.append(score)
    ep_history.append(agent.epsilon)

    avg_score= np.mean(scores)


    steps=steps+1
    

#---- BE CAREFUL OF THE WHILE !!! HERE IS EPIDOSE ENDING--------
  #print("Reward",eps_rew,"Episode",i,"Steps" , steps)
  eps_rew+=reward
  step_list.append(steps)
  

  val = info.values()
  list_val=list(val)
  score_list.append(list_val)

  rew_list.append(eps_rew)
  episode = episode +1 

  print("---Episode reward:", reward ,"score",list_val,"steps",steps,"episode=",i,"---")
  #terminate if 500 episodes are correct 
  if(terminal ==30):
    print("!!! END OF TRAINING 20 CONTINUOUS GOALS !!!")
    print("---Avg reward last:", np.mean(rew_list[-10:]),"Avg score last",np.mean(score_list[-10:]),"Avg steps",np.mean(step_list[-10:]),"episode=",i,"---")
    all_prints.rew_graph(rew_list[-i:],i)
    all_prints.step_graph(goal_steps[-20:],20)
    break

# PRINTS
  if (i % 10)== 0 :
      print("---Avg reward last:", np.mean(rew_list[-10:]),"Avg score last",np.mean(score_list[-10:]),"Avg steps",np.mean(step_list[-10:]),"episode=",i,"---")
      #print(score_list)

  if (((i % 1000)== 0) and i!=0) :
      all_prints.score_graph(score_list[-1000:],1000)# graph the last 1000 episodes
  if(((i%50)==0) and i!=0):
    all_prints.rew_graph(rew_list[-i:],i)
     
  
  #EPISODE PRINTS
  #all_prints.printstats(i,rew_list,eps_rew,agent.epsilon)
  
  #eps_rew=0 #GIA NA BGALO SYNOLIKO GRAFIMA TO AFAIRO AYTO



#print("Avg score last:", np.mean(rew_list[-10:]),"Avg score",np.mean(score_list),"Avg steps",np.mean(step_list[-10:]),"episode=",i)
#all_prints.score_graph(score_list[-1000:],1000)# graph the last 1000 episodes
      
a = len(goal_steps)
all_prints.step_graph(goal_steps[-a:],len(goal_steps))
# Out:
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# dribble prin ton antipalo
# PROSOXI lathos sprint
# dribble prin ton antipalo
# dribble prin ton antipalo
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# ball is out -15 episode 0 Ball Position 0.6376257 -0.42286187 6.5417404 step= 83
# PROSOXI lathos sprint
# ---Episode reward: -20.155086839560376 score [0] steps 84 episode= 0 ---
# ---Avg reward last: -20.155086839560376 Avg score last 0.0 Avg steps 84.0 episode= 0 ---
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# dribble prin ton antipalo
# sprint afou exei perasei
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# sprint afou exei perasei
# klepsimo
# ---Episode reward: -30.22689166104326 score [0] steps 78 episode= 1 ---
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# klepsimo
# ---Episode reward: -30.17303427786155 score [0] steps 59 episode= 2 ---
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# dribble prin ton antipalo
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# sprint afou exei perasei
# sprint afou exei perasei
# Mpala piso apo kentro
# perase ton antipalo kanonika
# ---Episode reward: -9.289504886932589 score [0] steps 68 episode= 3 ---
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# dribble prin ton antipalo
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# Mpala piso apo kentro
# sprint afou exei perasei
# ---Episode reward: -23.30460119131403 score [0] steps 75 episode= 4 ---
# dribble prin ton antipalo
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# sprint afou exei perasei
# ball is out -15 episode 5 Ball Position 0.5080576 0.4251339 6.445884 step= 89
# ---Episode reward: -10.18075309020026 score [0] steps 90 episode= 5 ---
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# dribble prin ton antipalo
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# ball is out -15 episode 6 Ball Position 0.17997569 -0.43193403 10.00167 step= 67
# ---Episode reward: -15.260953222758364 score [0] steps 68 episode= 6 ---
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# dribble prin ton antipalo
# dribble prin ton antipalo
# dribble prin ton antipalo
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# ball is out -15 episode 7 Ball Position 0.6318847 0.4289938 0.10935705 step= 82
# ---Episode reward: -10.157582710191472 score [0] steps 83 episode= 7 ---
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# dribble prin ton antipalo
# PROSOXI lathos sprint
# Mpala piso apo kentro
# dribble prin ton antipalo
# ---Episode reward: -25.293443252862346 score [0] steps 70 episode= 8 ---
# dribble prin ton antipalo
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# dribble prin ton antipalo
# PROSOXI lathos sprint
# sprint afou exei perasei
# ball is out -15 episode 9 Ball Position 0.71147525 -0.430218 0.10999521 step= 92
# ---Episode reward: -15.145446129073939 score [0] steps 93 episode= 9 ---
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# dribble prin ton antipalo
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# dribble prin ton antipalo
# PROSOXI lathos sprint
# sprint afou exei perasei
# sprint afou exei perasei
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# shout entos periohis Ball Position 0.7640544 -0.20947161 1.8210706 episode 10 step= 82
# Ball is out by player - 5
# ---Episode reward: -5.105235230634401 score [0] steps 129 episode= 10 ---
# ---Avg reward last: -17.413744565287224 Avg score last 0.0 Avg steps 81.3 episode= 10 ---
# PROSOXI lathos sprint
# sprint afou exei perasei
# Mpala piso apo kentro
# sprint afou exei perasei
# ---Episode reward: -23.29006806915198 score [0] steps 80 episode= 11 ---
# shout entos periohis Ball Position 0.82553905 -0.011222605 0.12651893 episode 12 step= 89
# goal episode 12 step= 98
# ---Episode reward: 50.977553636670564 score [1] steps 99 episode= 12 ---
# dribble prin ton antipalo
# klepsimo
# ---Episode reward: -30.152025217705397 score [0] steps 59 episode= 13 ---
# dribble prin ton antipalo
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# shout entos periohis Ball Position 0.91931736 0.051159367 0.14635456 episode 14 step= 127
# klepsimo
# ---Episode reward: -30.10778908229836 score [0] steps 185 episode= 14 ---
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# shout entos periohis Ball Position 0.98338765 0.0020731818 0.110530555 episode 15 step= 125
# goal episode 15 step= 133
# ---Episode reward: 50.978681584431975 score [1] steps 134 episode= 15 ---
# PROSOXI lathos sprint
# klepsimo
# ---Episode reward: -30.144339881760885 score [0] steps 69 episode= 16 ---
# sprint afou exei perasei
# sprint afou exei perasei
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# ball is out -15 episode 17 Ball Position 0.14826149 0.43308258 1.0159459 step= 74
# perase ton antipalo kanonika
# ---Episode reward: -9.269419043090755 score [0] steps 75 episode= 17 ---
# klepsimo
# ---Episode reward: -25.161757260463485 score [0] steps 59 episode= 18 ---
# shout entos periohis Ball Position 0.6716641 -0.05469184 0.11113935 episode 19 step= 89
# klepsimo
# ---Episode reward: -30.041974070244997 score [0] steps 100 episode= 19 ---
# sprint afou exei perasei
# klepsimo
# ---Episode reward: -25.017631732445356 score [0] steps 103 episode= 20 ---
# ---Avg reward last: -10.122876913605868 Avg score last 0.2 Avg steps 96.3 episode= 20 ---
# shout entos periohis Ball Position 0.799495 -0.24445206 9.354039 episode 21 step= 87
# Ball is out by player - 5
# ---Episode reward: -5.1260575353780755 score [0] steps 96 episode= 21 ---
# shout entos periohis Ball Position 0.9823059 -0.00022986258 0.12099019 episode 22 step= 87
# goal episode 22 step= 89
# ---Episode reward: 50.97715492131533 score [1] steps 90 episode= 22 ---
# shout entos periohis Ball Position 0.79169124 -0.0047711115 0.109466605 episode 23 step= 93
# Ball is out by player - 5
# ---Episode reward: -5.037890405032903 score [0] steps 107 episode= 23 ---
# shout entos periohis Ball Position 0.854992 0.10785267 0.13322927 episode 24 step= 90
# Ball is out by player - 5
# ---Episode reward: -5.030512953571717 score [0] steps 98 episode= 24 ---
# shout entos periohis Ball Position 0.93999135 0.015053316 0.110966735 episode 25 step= 100
# goal episode 25 step= 104
# ---Episode reward: 50.97551940852566 score [1] steps 105 episode= 25 ---
# PROSOXI lathos sprint
# shout entos periohis Ball Position 0.7831509 0.003041425 0.10795214 episode 26 step= 83
# goal episode 26 step= 92
# ---Episode reward: 50.97851249106871 score [1] steps 93 episode= 26 ---
# klepsimo
# ---Episode reward: -25.09051825600967 score [0] steps 80 episode= 27 ---
# goal episode 28 step= 106
# ---Episode reward: 50.97755137900249 score [1] steps 107 episode= 28 ---
# shout entos periohis Ball Position 0.86107147 0.011436105 0.1442999 episode 29 step= 92
# goal episode 29 step= 100
# ---Episode reward: 50.97645953915017 score [1] steps 101 episode= 29 ---
# goal episode 30 step= 123
# ---Episode reward: 50.97563345927836 score [1] steps 124 episode= 30 ---
# ---Avg reward last: 26.55758520483484 Avg score last 0.6 Avg steps 100.1 episode= 30 ---
# shout entos periohis Ball Position 0.94630164 0.013692194 0.1114444 episode 31 step= 106
# goal episode 31 step= 110
# ---Episode reward: 50.98046538555844 score [1] steps 111 episode= 31 ---
# ball is out -15 episode 32 Ball Position 1.0055897 -0.13069652 5.931681 step= 103
# ---Episode reward: -10.044562361386966 score [0] steps 104 episode= 32 ---
# klepsimo
# ---Episode reward: -25.08588965635496 score [0] steps 83 episode= 33 ---
# goal episode 34 step= 104
# ---Episode reward: 50.97521526156238 score [1] steps 105 episode= 34 ---
# shout entos periohis Ball Position 0.9282338 -0.39531276 0.11037361 episode 35 step= 93
# Ball is out by player - 5
# ---Episode reward: -5.1299308793747525 score [0] steps 103 episode= 35 ---
# PROSOXI lathos sprint
# ball is out -15 episode 36 Ball Position 0.70006156 -0.43273237 0.10992913 step= 87
# ---Episode reward: -10.147718665041351 score [0] steps 88 episode= 36 ---
# shout entos periohis Ball Position 0.87566364 0.0047930633 0.12160639 episode 37 step= 95
# goal episode 37 step= 100
# ---Episode reward: 50.97752948447133 score [1] steps 101 episode= 37 ---
# klepsimo
# ---Episode reward: -25.021541809611307 score [0] steps 95 episode= 38 ---
# ball is out -15 episode 39 Ball Position 0.8904844 0.429175 9.9780245 step= 95
# PROSOXI lathos sprint
# ---Episode reward: -20.12944324230727 score [0] steps 96 episode= 39 ---
# shout entos periohis Ball Position 0.979766 0.06853 1.6754992 episode 40 step= 100
# Ball is out by player - 5
# ---Episode reward: -5.035583740748497 score [0] steps 102 episode= 40 ---
# ---Avg reward last: 5.233853977676704 Avg score last 0.3 Avg steps 98.8 episode= 40 ---
# klepsimo
# ---Episode reward: -25.01268581281748 score [0] steps 104 episode= 41 ---
# shout entos periohis Ball Position 0.8686968 0.25497317 0.96703476 episode 42 step= 80
# Ball is out by player - 5
# ---Episode reward: -5.1079194101149 score [0] steps 93 episode= 42 ---
# sprint afou exei perasei
# ball is out -15 episode 43 Ball Position 0.87201726 0.42763686 0.26422215 step= 91
# ---Episode reward: -15.12967501667752 score [0] steps 92 episode= 43 ---
# goal episode 44 step= 108
# ---Episode reward: 50.97685690542142 score [1] steps 109 episode= 44 ---
# goal episode 45 step= 102
# ---Episode reward: 50.978315452932904 score [1] steps 103 episode= 45 ---
# shout entos periohis Ball Position 0.966072 -0.04263745 0.11266215 episode 46 step= 103
# goal episode 46 step= 106
# ---Episode reward: 50.976548011572014 score [1] steps 107 episode= 46 ---
# shout entos periohis Ball Position 0.94768363 0.009495839 0.110752 episode 47 step= 101
# goal episode 47 step= 107
# ---Episode reward: 50.978517049147726 score [1] steps 108 episode= 47 ---
# shout entos periohis Ball Position 0.82390976 0.010832044 0.14801204 episode 48 step= 89
# goal episode 48 step= 97
# ---Episode reward: 50.981166787026446 score [1] steps 98 episode= 48 ---
# shout entos periohis Ball Position 0.8926592 -0.013744998 0.119433105 episode 49 step= 97
# goal episode 49 step= 102
# ---Episode reward: 50.987600361985926 score [1] steps 103 episode= 49 ---
# goal episode 50 step= 108
# ---Episode reward: 50.97628091560777 score [1] steps 109 episode= 50 ---
# ---Avg reward last: 31.160500524408434 Avg score last 0.7 Avg steps 102.6 episode= 50 ---
# sprint afou exei perasei
# sprint afou exei perasei
# ball is out -15 episode 51 Ball Position 0.81980413 0.4299662 1.7853914 step= 99
# ---Episode reward: -10.13353910580628 score [0] steps 100 episode= 51 ---
# shout entos periohis Ball Position 0.8130471 0.05012332 0.11083604 episode 52 step= 85
# goal episode 52 step= 91
# ---Episode reward: 50.986031313848756 score [1] steps 92 episode= 52 ---
# dribble prin ton antipalo
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# ball is out -15 episode 53 Ball Position 1.0152762 -0.32346383 0.10967547 step= 89
# ---Episode reward: -15.0999829002339 score [0] steps 90 episode= 53 ---
# PROSOXI lathos sprint
# sprint afou exei perasei
# sprint afou exei perasei
# ball is out -15 episode 54 Ball Position 0.8380478 -0.42876074 0.10585028 step= 92
# ---Episode reward: -15.131875679532683 score [0] steps 93 episode= 54 ---
# shout entos periohis Ball Position 0.99622566 0.002297658 0.15506569 episode 55 step= 112
# goal episode 55 step= 114
# ---Episode reward: 50.97677746943021 score [1] steps 115 episode= 55 ---
# shout entos periohis Ball Position 0.7931368 -0.009636055 0.10985251 episode 56 step= 89
# goal episode 56 step= 95
# ---Episode reward: 50.98306107672878 score [1] steps 96 episode= 56 ---
# dribble prin ton antipalo
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# shout entos periohis Ball Position 0.9702811 -0.35540378 0.10971953 episode 57 step= 91
# Ball is out by player - 5
# ---Episode reward: -5.119365470930168 score [0] steps 100 episode= 57 ---
# shout entos periohis Ball Position 0.90276206 -0.007849343 0.13162765 episode 58 step= 99
# goal episode 58 step= 104
# ---Episode reward: 50.98992884361625 score [1] steps 105 episode= 58 ---
# shout entos periohis Ball Position 0.8095939 0.02038718 0.11112399 episode 59 step= 87
# goal episode 59 step= 97
# ---Episode reward: 50.9773308407808 score [1] steps 98 episode= 59 ---
# shout entos periohis Ball Position 0.8636052 -0.040896956 1.3746446 episode 60 step= 95
# Ball is out by player - 5
# ---Episode reward: -5.069752552725527 score [0] steps 121 episode= 60 ---
# ---Avg reward last: 20.435861383517626 Avg score last 0.5 Avg steps 101.0 episode= 60 ---
# shout entos periohis Ball Position 0.9150784 0.0042029307 0.11129158 episode 61 step= 97
# goal episode 61 step= 101
# ---Episode reward: 50.986412330650374 score [1] steps 102 episode= 61 ---
# shout entos periohis Ball Position 0.8499507 0.0338884 0.23168425 episode 62 step= 87
# goal episode 62 step= 100
# ---Episode reward: 50.97480426861376 score [1] steps 101 episode= 62 ---
# shout entos periohis Ball Position 0.9649504 -0.066193655 0.44470352 episode 63 step= 110
# Ball is out by player - 5
# ---Episode reward: -5.132895009947698 score [0] steps 152 episode= 63 ---
# klepsimo
# ---Episode reward: -25.079517180488267 score [0] steps 84 episode= 64 ---
# shout entos periohis Ball Position 0.86427516 -0.0033459982 0.12451699 episode 65 step= 93
# goal episode 65 step= 98
# ---Episode reward: 50.97841620261573 score [1] steps 99 episode= 65 ---
# shout entos periohis Ball Position 0.72057366 0.062584676 0.13042563 episode 66 step= 76
# goal episode 66 step= 84
# ---Episode reward: 50.97692707126307 score [1] steps 85 episode= 66 ---
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# ball is out -15 episode 67 Ball Position 1.0085626 0.37556654 0.1388232 step= 127
# ---Episode reward: -10.11481093618461 score [0] steps 128 episode= 67 ---
# shout entos periohis Ball Position 0.81583846 -0.045354944 0.718466 episode 68 step= 80
# Ball is out by player - 5
# ---Episode reward: -5.055664908011587 score [0] steps 92 episode= 68 ---
# shout entos periohis Ball Position 0.9304787 0.023688931 0.11064156 episode 69 step= 101
# goal episode 69 step= 106
# ---Episode reward: 50.9751858447957 score [1] steps 107 episode= 69 ---
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# ball is out -15 episode 70 Ball Position 0.53918326 0.43528795 8.381442 step= 129
# ---Episode reward: -10.176502647168576 score [0] steps 130 episode= 70 ---
# ---Avg reward last: 19.93323550361379 Avg score last 0.5 Avg steps 108.0 episode= 70 ---
# shout entos periohis Ball Position 0.7952616 -0.11091372 4.265686 episode 71 step= 89
# Ball is out by player - 5
# ---Episode reward: -5.133046424265971 score [0] steps 119 episode= 71 ---
# shout entos periohis Ball Position 0.9143538 -0.023139883 0.10950356 episode 72 step= 98
# goal episode 72 step= 102
# ---Episode reward: 50.97770514510051 score [1] steps 103 episode= 72 ---
# goal episode 73 step= 111
# ---Episode reward: 50.97712627926542 score [1] steps 112 episode= 73 ---
# shout entos periohis Ball Position 0.84078366 -0.008761763 0.11113055 episode 74 step= 118
# goal episode 74 step= 127
# ---Episode reward: 50.98113814136715 score [1] steps 128 episode= 74 ---
# shout entos periohis Ball Position 0.74828 -0.011251147 0.11179437 episode 75 step= 83
# goal episode 75 step= 95
# ---Episode reward: 50.97591157273769 score [1] steps 96 episode= 75 ---
# ball is out -15 episode 76 Ball Position 1.0134467 0.42630565 0.10976119 step= 105
# ---Episode reward: -10.13003897586554 score [0] steps 106 episode= 76 ---
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# klepsimo
# Mpala piso apo kentro
# ---Episode reward: -55.28533084740365 score [0] steps 92 episode= 77 ---
# shout entos periohis Ball Position 0.9094384 -0.05823448 1.6544613 episode 78 step= 97
# Ball is out by player - 5
# ---Episode reward: -5.058071095953251 score [0] steps 104 episode= 78 ---
# ball is out -15 episode 79 Ball Position 0.9077523 -0.43457833 0.12438652 step= 90
# ---Episode reward: -10.130629509120187 score [0] steps 91 episode= 79 ---
# sprint afou exei perasei
# shout entos periohis Ball Position 0.9261115 -0.006618447 0.11192202 episode 80 step= 103
# goal episode 80 step= 107
# ---Episode reward: 50.97646641214051 score [1] steps 108 episode= 80 ---
# ---Avg reward last: 16.915123069800266 Avg score last 0.5 Avg steps 105.9 episode= 80 ---
# shout entos periohis Ball Position 0.8353106 -0.011028836 0.1313792 episode 81 step= 91
# goal episode 81 step= 98
# ---Episode reward: 50.97658072320909 score [1] steps 99 episode= 81 ---
# shout entos periohis Ball Position 0.8771988 0.0076011815 0.11133672 episode 82 step= 94
# goal episode 82 step= 101
# ---Episode reward: 50.97643461376781 score [1] steps 102 episode= 82 ---
# shout entos periohis Ball Position 0.7967888 -0.015257898 0.14637195 episode 83 step= 86
# goal episode 83 step= 92
# ---Episode reward: 50.987021341982654 score [1] steps 93 episode= 83 ---
# shout entos periohis Ball Position 0.8030329 0.049427696 0.11921447 episode 84 step= 86
# goal episode 84 step= 92
# ---Episode reward: 50.98493091867616 score [1] steps 93 episode= 84 ---
# shout entos periohis Ball Position 0.88505954 -0.0026527005 0.10895182 episode 85 step= 79
# goal episode 85 step= 84
# ---Episode reward: 50.98642090918592 score [1] steps 85 episode= 85 ---
# shout entos periohis Ball Position 0.8832135 0.006426553 0.12650616 episode 86 step= 93
# goal episode 86 step= 104
# ---Episode reward: 50.977922587270456 score [1] steps 105 episode= 86 ---
# dribble prin ton antipalo
# dribble prin ton antipalo
# dribble prin ton antipalo
# dribble prin ton antipalo
# goal episode 87 step= 107
# ---Episode reward: 55.974976816908786 score [1] steps 108 episode= 87 ---
# goal episode 88 step= 115
# ---Episode reward: 55.97656051952436 score [1] steps 116 episode= 88 ---
# shout entos periohis Ball Position 0.8772374 0.012980935 0.13319354 episode 89 step= 93
# goal episode 89 step= 99
# ---Episode reward: 50.981638432035744 score [1] steps 100 episode= 89 ---
# shout entos periohis Ball Position 0.97500885 0.018439053 0.11131356 episode 90 step= 101
# goal episode 90 step= 105
# ---Episode reward: 50.975946636770146 score [1] steps 106 episode= 90 ---
# ---Avg reward last: 51.97984334993312 Avg score last 1.0 Avg steps 100.7 episode= 90 ---
# dribble prin ton antipalo
# shout entos periohis Ball Position 0.9316647 0.027421966 0.11308648 episode 91 step= 104
# goal episode 91 step= 107
# ---Episode reward: 50.987338742535776 score [1] steps 108 episode= 91 ---
# klepsimo
# ---Episode reward: -30.071959303184478 score [0] steps 86 episode= 92 ---
# shout entos periohis Ball Position 0.95557356 -0.0096856095 0.11128151 episode 93 step= 103
# goal episode 93 step= 106
# ---Episode reward: 50.98464489084091 score [1] steps 107 episode= 93 ---
# Mpala piso apo kentro
# ---Episode reward: -25.28768121666057 score [0] steps 60 episode= 94 ---
# dribble prin ton antipalo
# dribble prin ton antipalo
# klepsimo
# dribble prin ton antipalo
# ---Episode reward: -30.05363475355854 score [0] steps 83 episode= 95 ---
# shout entos periohis Ball Position 0.8212227 0.0032772191 0.11372898 episode 96 step= 89
# goal episode 96 step= 95
# ---Episode reward: 50.97709280743324 score [1] steps 96 episode= 96 ---
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# sprint afou exei perasei
# Mpala piso apo kentro
# ---Episode reward: -35.28610550192286 score [0] steps 96 episode= 97 ---
# ball is out -15 episode 98 Ball Position 1.0080502 -0.08115039 0.10985607 step= 108
# ---Episode reward: -10.032755986067912 score [0] steps 109 episode= 98 ---
# dribble prin ton antipalo
# dribble prin ton antipalo
# PROSOXI lathos sprint
# ball is out -15 episode 99 Ball Position 0.69055885 -0.43261433 1.881838 step= 93
# ---Episode reward: -10.149069100695337 score [0] steps 94 episode= 99 ---
# klepsimo
# ---Episode reward: -30.067875827481384 score [0] steps 86 episode= 100 ---
# ---Avg reward last: -1.8000005248761162 Avg score last 0.3 Avg steps 92.5 episode= 100 ---
# goal episode 101 step= 107
# ---Episode reward: 55.97763866579082 score [1] steps 108 episode= 101 ---
# klepsimo
# ---Episode reward: -30.071226368467013 score [0] steps 86 episode= 102 ---
# PROSOXI lathos sprint
# ball is out -15 episode 103 Ball Position 1.0081087 -0.35098603 0.10962798 step= 89
# ---Episode reward: -15.107555787703145 score [0] steps 90 episode= 103 ---
# dribble prin ton antipalo
# goal episode 104 step= 108
# ---Episode reward: 50.97697433973444 score [1] steps 109 episode= 104 ---
# dribble prin ton antipalo
# shout entos periohis Ball Position 0.9373585 -0.0038120185 0.11085586 episode 105 step= 100
# goal episode 105 step= 104
# ---Episode reward: 50.9832717252387 score [1] steps 105 episode= 105 ---
# goal episode 106 step= 108
# ---Episode reward: 55.97859804671367 score [1] steps 109 episode= 106 ---
# dribble prin ton antipalo
# klepsimo
# ---Episode reward: -30.06568016768452 score [0] steps 97 episode= 107 ---
# ball is out -15 episode 108 Ball Position 1.0081336 0.34673774 0.114505 step= 94
# ---Episode reward: -10.10630994002555 score [0] steps 95 episode= 108 ---
# shout entos periohis Ball Position 0.99938387 -0.0034285919 0.11040993 episode 109 step= 101
# goal episode 109 step= 102
# ---Episode reward: 50.977315800550834 score [1] steps 103 episode= 109 ---
# dribble prin ton antipalo
# dribble prin ton antipalo
# dribble prin ton antipalo
# Ball is out by player - 5
# shout entos periohis Ball Position 0.9545731 -0.40680045 1.0619588 episode 110 step= 129
# ---Episode reward: 4.8778186838602915 score [0] steps 130 episode= 110 ---
# ---Avg reward last: 18.44208449980085 Avg score last 0.5 Avg steps 103.2 episode= 110 ---
# shout entos periohis Ball Position 0.8865691 -0.010343082 0.11459192 episode 111 step= 96
# goal episode 111 step= 102
# ---Episode reward: 50.980947704120254 score [1] steps 103 episode= 111 ---
# klepsimo
# ---Episode reward: -30.074089916506015 score [0] steps 85 episode= 112 ---
# PROSOXI lathos sprint
# dribble prin ton antipalo
# shout entos periohis Ball Position 0.840637 -0.18876506 1.3673409 episode 113 step= 81
# Ball is out by player - 5
# ---Episode reward: -5.105280601042634 score [0] steps 91 episode= 113 ---
# shout entos periohis Ball Position 0.91043913 0.018035615 0.89305794 episode 114 step= 104
# goal episode 114 step= 114
# ---Episode reward: 50.97629671321398 score [1] steps 115 episode= 114 ---
# shout entos periohis Ball Position 0.7865491 -0.008717792 0.12078648 episode 115 step= 83
# goal episode 115 step= 92
# ---Episode reward: 50.980823792395654 score [1] steps 93 episode= 115 ---
# shout entos periohis Ball Position 0.8418555 -0.039392684 1.5690176 episode 116 step= 98
# Ball is out by player - 5
# ---Episode reward: -5.125749118760941 score [0] steps 114 episode= 116 ---
# dribble prin ton antipalo
# dribble prin ton antipalo
# dribble prin ton antipalo
# dribble prin ton antipalo
# klepsimo
# dribble prin ton antipalo
# ---Episode reward: -30.07361741543733 score [0] steps 83 episode= 117 ---
# shout entos periohis Ball Position 0.988104 -0.032416217 0.11128617 episode 118 step= 106
# Ball is out by player - 5
# ---Episode reward: -5.118126839324566 score [0] steps 163 episode= 118 ---
# shout entos periohis Ball Position 0.9639164 0.00071611523 0.41557857 episode 119 step= 102
# Ball is out by player - 5
# ---Episode reward: -5.026547119930618 score [0] steps 106 episode= 119 ---
# dribble prin ton antipalo
# dribble prin ton antipalo
# dribble prin ton antipalo
# klepsimo
# ---Episode reward: -30.018017354055573 score [0] steps 100 episode= 120 ---
# ---Avg reward last: 4.239663984467223 Avg score last 0.3 Avg steps 105.3 episode= 120 ---
# goal episode 121 step= 117
# ---Episode reward: 50.97846568979817 score [1] steps 118 episode= 121 ---
# shout entos periohis Ball Position 0.80431795 -0.01247874 0.110979944 episode 122 step= 88
# goal episode 122 step= 94
# ---Episode reward: 50.980932922580436 score [1] steps 95 episode= 122 ---
# shout entos periohis Ball Position 0.9747055 -0.021098666 0.10938839 episode 123 step= 105
# goal episode 123 step= 109
# ---Episode reward: 50.973401344867455 score [1] steps 110 episode= 123 ---
# shout entos periohis Ball Position 0.68661046 -0.02357724 0.38057375 episode 124 step= 78
# goal episode 124 step= 103
# ---Episode reward: 50.97536537164939 score [1] steps 104 episode= 124 ---
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# ball is out -15 episode 125 Ball Position 1.0110914 0.29785004 0.1092807 step= 104
# sprint afou exei perasei
# ---Episode reward: -13.092224772960568 score [0] steps 105 episode= 125 ---
# shout entos periohis Ball Position 0.94246185 -0.004490548 0.11132201 episode 126 step= 110
# goal episode 126 step= 115
# ---Episode reward: 50.97861067360283 score [1] steps 116 episode= 126 ---
# shout entos periohis Ball Position 0.93878466 0.009566206 0.10892654 episode 127 step= 100
# goal episode 127 step= 103
# ---Episode reward: 50.987937206739375 score [1] steps 104 episode= 127 ---
# dribble prin ton antipalo
# goal episode 128 step= 103
# ---Episode reward: 55.97715424145715 score [1] steps 104 episode= 128 ---
# shout entos periohis Ball Position 0.8183754 -0.0066104396 0.11243489 episode 129 step= 87
# goal episode 129 step= 93
# ---Episode reward: 50.978063342663994 score [1] steps 94 episode= 129 ---
# shout entos periohis Ball Position 1.0043894 -0.026761528 0.111978434 episode 130 step= 110
# goal episode 130 step= 111
# ---Episode reward: 50.9751366217678 score [1] steps 112 episode= 130 ---
# ---Avg reward last: 45.0712842642166 Avg score last 0.9 Avg steps 106.2 episode= 130 ---
# klepsimo
# ---Episode reward: -30.052976572264956 score [0] steps 86 episode= 131 ---
# klepsimo
# ---Episode reward: -30.153336172115058 score [0] steps 55 episode= 132 ---
# shout entos periohis Ball Position 0.679038 -0.028486377 1.305006 episode 133 step= 80
# Ball is out by player - 5
# ---Episode reward: -5.142855457750623 score [0] steps 119 episode= 133 ---
# klepsimo
# ---Episode reward: -30.08203857210049 score [0] steps 76 episode= 134 ---
# shout entos periohis Ball Position 0.88268834 0.07254647 0.1651506 episode 135 step= 87
# Ball is out by player - 5
# ---Episode reward: -5.036334427773715 score [0] steps 100 episode= 135 ---
# shout entos periohis Ball Position 0.7745484 -0.07925254 0.11096673 episode 136 step= 89
# goal episode 136 step= 96
# ---Episode reward: 50.97646429570364 score [1] steps 97 episode= 136 ---
# shout entos periohis Ball Position 0.83745354 -0.0025990624 0.11086031 episode 137 step= 90
# goal episode 137 step= 107
# ---Episode reward: 50.97730554369917 score [1] steps 108 episode= 137 ---
# ball is out -15 episode 138 Ball Position 0.8825601 0.430123 9.930622 step= 93
# ---Episode reward: -10.129992372035893 score [0] steps 94 episode= 138 ---
# shout entos periohis Ball Position 0.9325203 0.08049944 0.10953634 episode 139 step= 96
# Ball is out by player - 5
# ---Episode reward: -5.029026033493987 score [0] steps 103 episode= 139 ---
# shout entos periohis Ball Position 0.7942562 0.006110558 0.7251786 episode 140 step= 86
# Ball is out by player - 5
# ---Episode reward: -5.13258274438745 score [0] steps 117 episode= 140 ---
# ---Avg reward last: -1.8805372512519365 Avg score last 0.2 Avg steps 95.5 episode= 140 ---
# shout entos periohis Ball Position 0.86355776 0.00077183364 0.11252734 episode 141 step= 95
# goal episode 141 step= 100
# ---Episode reward: 50.977873182165155 score [1] steps 101 episode= 141 ---
# PROSOXI lathos sprint
# shout entos periohis Ball Position 0.80285114 0.086956315 0.18442161 episode 142 step= 85
# Ball is out by player - 5
# ---Episode reward: -5.032702494839964 score [0] steps 97 episode= 142 ---
# shout entos periohis Ball Position 0.7682084 0.016107813 0.13204838 episode 143 step= 85
# goal episode 143 step= 92
# ---Episode reward: 50.977413154788536 score [1] steps 93 episode= 143 ---
# klepsimo
# ---Episode reward: -30.010133229705097 score [0] steps 101 episode= 144 ---
# shout entos periohis Ball Position 0.8053642 0.007841273 0.14285661 episode 145 step= 87
# goal episode 145 step= 96
# ---Episode reward: 50.978707558412175 score [1] steps 97 episode= 145 ---
# shout entos periohis Ball Position 0.94064385 -0.03536088 0.11211547 episode 146 step= 102
# Ball is out by player - 5
# ---Episode reward: -5.0946643658503605 score [0] steps 147 episode= 146 ---
# PROSOXI lathos sprint
# klepsimo
# ---Episode reward: -30.129497445270207 score [0] steps 48 episode= 147 ---
# ball is out -15 episode 148 Ball Position 1.0077407 0.05821629 0.11010687 step= 96
# ---Episode reward: -10.027950520297411 score [0] steps 97 episode= 148 ---
# shout entos periohis Ball Position 0.8490209 0.009510284 0.60409707 episode 149 step= 92
# Ball is out by player - 5
# ---Episode reward: -5.071228319022857 score [0] steps 118 episode= 149 ---
# shout entos periohis Ball Position 0.9494183 -0.004876118 0.11046742 episode 150 step= 91
# goal episode 150 step= 94
# ---Episode reward: 50.98365451110362 score [1] steps 95 episode= 150 ---
# ---Avg reward last: 11.85514720314836 Avg score last 0.4 Avg steps 99.4 episode= 150 ---
# shout entos periohis Ball Position 0.8595041 0.0037564866 0.13779366 episode 151 step= 88
# goal episode 151 step= 94
# ---Episode reward: 50.9854059525592 score [1] steps 95 episode= 151 ---
# shout entos periohis Ball Position 0.79463786 -0.008250792 0.9918549 episode 152 step= 86
# Ball is out by player - 5
# ---Episode reward: -5.129652745780499 score [0] steps 120 episode= 152 ---
# shout entos periohis Ball Position 0.88363284 0.0013910366 0.11210052 episode 153 step= 96
# goal episode 153 step= 100
# ---Episode reward: 50.98932648623295 score [1] steps 101 episode= 153 ---
# shout entos periohis Ball Position 0.76212484 -0.0069501805 0.13550125 episode 154 step= 87
# goal episode 154 step= 99
# ---Episode reward: 50.978235545369486 score [1] steps 100 episode= 154 ---
# PROSOXI lathos sprint
# ball is out -15 episode 155 Ball Position 0.8276497 0.4234095 1.3495404 step= 97
# ---Episode reward: -10.13104186878479 score [0] steps 98 episode= 155 ---
# goal episode 156 step= 112
# shout entos periohis Ball Position 1.0125839 0.037938703 0.11122162 episode 156 step= 112
# ---Episode reward: 60.97409104534576 score [1] steps 113 episode= 156 ---
# shout entos periohis Ball Position 0.9510298 0.0385506 0.1177656 episode 157 step= 103
# goal episode 157 step= 106
# ---Episode reward: 50.98259251149059 score [1] steps 107 episode= 157 ---
# shout entos periohis Ball Position 0.8620664 0.0020033633 0.10898077 episode 158 step= 93
# goal episode 158 step= 99
# ---Episode reward: 50.97497218995424 score [1] steps 100 episode= 158 ---
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# ball is out -15 episode 159 Ball Position 0.8343745 0.43184942 8.674576 step= 96
# PROSOXI lathos sprint
# ---Episode reward: -20.133025363694756 score [0] steps 97 episode= 159 ---
# PROSOXI lathos sprint
# ball is out -15 episode 160 Ball Position 1.0061878 0.34886074 0.22396787 step= 95
# ---Episode reward: -10.106814964720694 score [0] steps 96 episode= 160 ---
# ---Avg reward last: 27.038408878797146 Avg score last 0.6 Avg steps 102.7 episode= 160 ---
# shout entos periohis Ball Position 0.88826656 -0.014811394 0.13503838 episode 161 step= 99
# goal episode 161 step= 105
# ---Episode reward: 50.98226878607167 score [1] steps 106 episode= 161 ---
# klepsimo
# ---Episode reward: -30.075669699681583 score [0] steps 85 episode= 162 ---
# klepsimo
# ---Episode reward: -30.028316285888156 score [0] steps 97 episode= 163 ---
# shout entos periohis Ball Position 0.88819 -0.02168019 0.722621 episode 164 step= 96
# Ball is out by player - 5
# ---Episode reward: -5.089788642434907 score [0] steps 124 episode= 164 ---
# klepsimo
# ---Episode reward: -30.050222343598634 score [0] steps 87 episode= 165 ---
# shout entos periohis Ball Position 0.74458575 -0.022252029 1.1294872 episode 166 step= 105
# Ball is out by player - 5
# ---Episode reward: -5.138296092895935 score [0] steps 139 episode= 166 ---
# klepsimo
# ---Episode reward: -30.067453425993428 score [0] steps 86 episode= 167 ---
# goal episode 168 step= 101
# ---Episode reward: 50.978339460446044 score [1] steps 102 episode= 168 ---
# ball is out -15 episode 169 Ball Position 0.77323544 0.42462453 0.10981005 step= 95
# ---Episode reward: -10.13631815349463 score [0] steps 96 episode= 169 ---
# shout entos periohis Ball Position 0.7334221 0.034633584 0.52879506 episode 170 step= 79
# Ball is out by player - 5
# ---Episode reward: -5.028727206388371 score [0] steps 100 episode= 170 ---
# ---Avg reward last: -4.365418360385793 Avg score last 0.2 Avg steps 102.2 episode= 170 ---
# klepsimo
# ---Episode reward: -30.082872657790695 score [0] steps 82 episode= 171 ---
# klepsimo
# ---Episode reward: -30.143022812528542 score [0] steps 54 episode= 172 ---
# shout entos periohis Ball Position 0.8525333 -0.018798219 0.15031534 episode 173 step= 96
# Ball is out by player - 5
# ---Episode reward: -5.0614110269966295 score [0] steps 112 episode= 173 ---
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# dribble prin ton antipalo
# ball is out -15 episode 174 Ball Position 1.0131913 -0.36975485 0.11076839 step= 90
# ---Episode reward: -10.113379575842023 score [0] steps 91 episode= 174 ---
# dribble prin ton antipalo
# klepsimo
# ---Episode reward: -30.086822093711532 score [0] steps 83 episode= 175 ---
# dribble prin ton antipalo
# ball is out -15 episode 176 Ball Position 1.0123854 -0.3568597 0.11048284 step= 90
# ---Episode reward: -10.109546161733881 score [0] steps 91 episode= 176 ---
# shout entos periohis Ball Position 0.87416136 0.030397594 0.4020103 episode 177 step= 93
# Ball is out by player - 5
# ---Episode reward: -5.079776771367355 score [0] steps 119 episode= 177 ---
# goal episode 178 step= 127
# ---Episode reward: 50.97826055115959 score [1] steps 128 episode= 178 ---
# shout entos periohis Ball Position 0.7799321 0.007940905 0.26067343 episode 179 step= 86
# goal episode 179 step= 104
# ---Episode reward: 50.97550115027235 score [1] steps 105 episode= 179 ---
# goal episode 180 step= 93
# ---Episode reward: 50.97659694337076 score [1] steps 94 episode= 180 ---
# ---Avg reward last: 3.225352754483205 Avg score last 0.3 Avg steps 95.9 episode= 180 ---
# shout entos periohis Ball Position 0.90291333 0.0061549987 0.59363717 episode 181 step= 96
# Ball is out by player - 5
# ---Episode reward: -5.057824075133226 score [0] steps 117 episode= 181 ---
# goal episode 182 step= 99
# ---Episode reward: 55.97730089632304 score [1] steps 100 episode= 182 ---
# shout entos periohis Ball Position 0.9656576 -0.00010440028 0.11074226 episode 183 step= 103
# goal episode 183 step= 106
# ---Episode reward: 50.97826551866935 score [1] steps 107 episode= 183 ---
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kai sprint NO REWARD
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# sprint afou exei perasei
# perase ton antipalo kanonika
# shout entos periohis Ball Position 0.003443477 0.07236394 0.15751891 episode 184 step= 89
# Mpala piso apo kentro
# perase ton antipalo kanonika
# ---Episode reward: -24.28212098916657 score [0] steps 91 episode= 184 ---
# dribble prin ton antipalo
# goal episode 185 step= 111
# ---Episode reward: 55.975055885544045 score [1] steps 112 episode= 185 ---
# ball is out -15 episode 186 Ball Position 1.010701 0.07224311 0.11111396 step= 104
# ---Episode reward: -10.031392243303493 score [0] steps 105 episode= 186 ---
# PROSOXI lathos sprint
# dribble prin ton antipalo
# PROSOXI lathos sprint
# ball is out -15 episode 187 Ball Position 0.928649 -0.43153048 0.110520616 step= 97
# ---Episode reward: -10.129473162405766 score [0] steps 98 episode= 187 ---
# klepsimo
# ---Episode reward: -30.020400252916744 score [0] steps 92 episode= 188 ---
# shout entos periohis Ball Position 0.8616535 0.017187957 0.13254175 episode 189 step= 95
# goal episode 189 step= 100
# ---Episode reward: 50.978283899097235 score [1] steps 101 episode= 189 ---
# goal episode 190 step= 104
# ---Episode reward: 50.97828923097137 score [1] steps 105 episode= 190 ---
# ---Avg reward last: 18.53659847076792 Avg score last 0.5 Avg steps 102.8 episode= 190 ---
# dribble prin ton antipalo
# shout entos periohis Ball Position 0.94109136 -0.02073197 0.11075819 episode 191 step= 103
# goal episode 191 step= 106
# ---Episode reward: 50.98676437757736 score [1] steps 107 episode= 191 ---
# shout entos periohis Ball Position 0.881563 0.001529981 0.11202642 episode 192 step= 88
# goal episode 192 step= 92
# ---Episode reward: 50.98853907218167 score [1] steps 93 episode= 192 ---
# shout entos periohis Ball Position 0.80045277 -0.004297547 0.58198094 episode 193 step= 88
# goal episode 193 step= 102
# ---Episode reward: 50.9776536625729 score [1] steps 103 episode= 193 ---
# goal episode 194 step= 87
# ---Episode reward: 55.97860325920841 score [1] steps 88 episode= 194 ---
# Mpala piso apo kentro
# ---Episode reward: -25.281981645240688 score [0] steps 72 episode= 195 ---
# shout entos periohis Ball Position 0.96289885 -0.008199277 0.12735657 episode 196 step= 105
# goal episode 196 step= 108
# ---Episode reward: 50.9798896883794 score [1] steps 109 episode= 196 ---
# goal episode 197 step= 109
# ---Episode reward: 50.9783781262707 score [1] steps 110 episode= 197 ---
# goal episode 198 step= 95
# ---Episode reward: 55.97793239433816 score [1] steps 96 episode= 198 ---
# ball is out -15 episode 199 Ball Position 0.99727535 -0.09303569 0.42195895 step= 102
# ---Episode reward: -15.033586415866381 score [0] steps 103 episode= 199 ---
# klepsimo
# ---Episode reward: -30.021515461753808 score [0] steps 104 episode= 200 ---
# ---Avg reward last: 29.653067705766773 Avg score last 0.7 Avg steps 98.5 episode= 200 ---
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# PROSOXI lathos sprint
# ball is out -15 episode 201 Ball Position 1.0159018 -0.28774968 0.111009285 step= 93
# ---Episode reward: -10.08967189142294 score [0] steps 94 episode= 201 ---
# shout entos periohis Ball Position 0.7243236 0.0056318915 0.28892508 episode 202 step= 78
# Ball is out by player - 5
# ---Episode reward: -5.075494779485637 score [0] steps 90 episode= 202 ---
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# sprint afou exei perasei
# perase ton antipalo kanonika
# perase ton antipalo kanonika
# sprint afou exei perasei
# ball is out -15 episode 203 Ball Position 0.058674313 -0.4336014 1.766665 step= 82
# perase ton antipalo kanonika
# sprint afou exei perasei
# ---Episode reward: -12.293319144001252 score [0] steps 83 episode= 203 ---
# PROSOXI lathos sprint
# ball is out -15 episode 204 Ball Position 1.0117812 0.30519974 8.405115 step= 104
# ---Episode reward: -10.094412930264296 score [0] steps 105 episode= 204 ---
# shout entos periohis Ball Position 0.90318227 0.011728769 0.11912426 episode 205 step= 96
# goal episode 205 step= 102
# ---Episode reward: 50.97727704448824 score [1] steps 103 episode= 205 ---
# ball is out -15 episode 206 Ball Position 0.7697522 0.43045354 8.803828 step= 86
# ---Episode reward: -10.138324753671359 score [0] steps 87 episode= 206 ---
# shout entos periohis Ball Position 0.69488376 -0.0077669434 0.11303111 episode 207 step= 81
# goal episode 207 step= 97
# ---Episode reward: 50.976790296393965 score [1] steps 98 episode= 207 ---
# shout entos periohis Ball Position 0.83225095 0.013236228 0.5689958 episode 208 step= 90
# goal episode 208 step= 105
# ---Episode reward: 50.97710317468981 score [1] steps 106 episode= 208 ---
# goal episode 209 step= 110
# ---Episode reward: 50.97821861879845 score [1] steps 111 episode= 209 ---
# goal episode 210 step= 111
# ---Episode reward: 50.976261051031905 score [1] steps 112 episode= 210 ---
# ---Avg reward last: 20.719442668655688 Avg score last 0.5 Avg steps 98.9 episode= 210 ---
