# %%
#https://www.kaggle.com/piotrstanczyk/gfootball-template-bot  G-FOOTBALL TEMPLATE BOT
# Install:
# Kaggle environments.
#!git clone https://github.com/Kaggle/kaggle-environments.git
#!cd kaggle-environments && pip install .

# GFootball environment.
# !apt-get update -y
# !apt-get install -y libsdl2-gfx-dev libsdl2-ttf-dev

# Make sure that the Branch in git clone and in wget call matches !!
# !git clone -b v5 https://github.com/Georgemouts/football.git #https://github.com/google-research/football.git  
# !mkdir -p football/third_party/gfootball_engine/lib

# !wget https://storage.googleapis.com/gfootball/prebuilt_gameplayfootball_v2.8.so -O football/third_party/gfootball_engine/lib/prebuilt_gameplayfootball.so
# !cd football && GFOOTBALL_USE_PREBUILT_SO=1 pip3 install .

# !pip install utils
#!pip install learning
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [770 kB]
# Hit:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [932 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [966 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,503 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [22.8 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,765 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,199 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,277 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [29.8 kB]
# Get:23 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [44.3 kB]
# Fetched 12.8 MB in 3s (4,226 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   dbus gir1.2-ibus-1.0 libcapnp-0.6.1 libdbus-1-3 libdbus-1-dev libibus-1.0-5
#   libibus-1.0-dev libmirclient-dev libmirclient9 libmircommon-dev
#   libmircommon7 libmircookie-dev libmircookie2 libmircore-dev libmircore1
#   libmirprotobuf3 libprotobuf-dev libprotobuf-lite10 libpulse-dev
#   libpulse-mainloop-glib0 libsdl2-dev libsdl2-gfx-1.0-0 libsdl2-ttf-2.0-0
#   libsndio-dev libudev-dev libxcursor-dev libxinerama-dev libxkbcommon-dev
#   libxrandr-dev libxv-dev x11proto-randr-dev x11proto-xinerama-dev
# Suggested packages:
#   default-dbus-session-bus | dbus-session-bus libsdl2-gfx-doc
# The following NEW packages will be installed:
#   gir1.2-ibus-1.0 libcapnp-0.6.1 libdbus-1-dev libibus-1.0-5 libibus-1.0-dev
#   libmirclient-dev libmirclient9 libmircommon-dev libmircommon7
#   libmircookie-dev libmircookie2 libmircore-dev libmircore1 libmirprotobuf3
#   libprotobuf-dev libprotobuf-lite10 libpulse-dev libpulse-mainloop-glib0
#   libsdl2-dev libsdl2-gfx-1.0-0 libsdl2-gfx-dev libsdl2-ttf-2.0-0
#   libsdl2-ttf-dev libsndio-dev libudev-dev libxcursor-dev libxinerama-dev
#   libxkbcommon-dev libxrandr-dev libxv-dev x11proto-randr-dev
#   x11proto-xinerama-dev
# The following packages will be upgraded:
#   dbus libdbus-1-3
# 2 upgraded, 32 newly installed, 0 to remove and 72 not upgraded.
# Need to get 4,244 kB of archives.
# After this operation, 24.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 dbus amd64 1.12.2-1ubuntu1.3 [150 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdbus-1-3 amd64 1.12.2-1ubuntu1.3 [175 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libibus-1.0-5 amd64 1.5.17-3ubuntu5.3 [133 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-ibus-1.0 amd64 1.5.17-3ubuntu5.3 [66.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcapnp-0.6.1 amd64 0.6.1-1ubuntu1 [658 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdbus-1-dev amd64 1.12.2-1ubuntu1.3 [165 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libibus-1.0-dev amd64 1.5.17-3ubuntu5.3 [145 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore1 amd64 0.31.1-0ubuntu1 [26.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon7 amd64 0.31.1-0ubuntu1 [73.9 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-lite10 amd64 3.0.0-9.1ubuntu1 [97.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirprotobuf3 amd64 0.31.1-0ubuntu1 [127 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient9 amd64 0.31.1-0ubuntu1 [199 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore-dev amd64 0.31.1-0ubuntu1 [21.7 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-dev amd64 3.0.0-9.1ubuntu1 [959 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxkbcommon-dev amd64 0.8.2-1~ubuntu18.04.1 [150 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon-dev amd64 0.31.1-0ubuntu1 [13.9 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie2 amd64 0.31.1-0ubuntu1 [19.7 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie-dev amd64 0.31.1-0ubuntu1 [4,392 B]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient-dev amd64 0.31.1-0ubuntu1 [47.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-mainloop-glib0 amd64 1:11.1-1ubuntu7.11 [22.1 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-dev amd64 1:11.1-1ubuntu7.11 [81.5 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsndio-dev amd64 1.1.0-3 [13.3 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libudev-dev amd64 237-3ubuntu10.53 [19.1 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor-dev amd64 1:1.1.15-1 [26.5 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xinerama-dev all 2018.4-4 [2,628 B]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama-dev amd64 2:1.1.3-1 [8,404 B]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-randr-dev all 2018.4-4 [2,620 B]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr-dev amd64 2:1.5.1-1 [24.0 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxv-dev amd64 2:1.0.11-1 [32.5 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsdl2-dev amd64 2.0.8+dfsg1-1ubuntu1.18.04.4 [683 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsdl2-gfx-1.0-0 amd64 1.0.4+dfsg-1 [29.9 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsdl2-gfx-dev amd64 1.0.4+dfsg-1 [29.8 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsdl2-ttf-2.0-0 amd64 2.0.14+dfsg1-2 [14.8 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsdl2-ttf-dev amd64 2.0.14+dfsg1-2 [19.7 kB]
# Fetched 4,244 kB in 2s (2,099 kB/s)
# Extracting templates from packages: 100%
# (Reading database ... 155203 files and directories currently installed.)
# Preparing to unpack .../00-dbus_1.12.2-1ubuntu1.3_amd64.deb ...
# Unpacking dbus (1.12.2-1ubuntu1.3) over (1.12.2-1ubuntu1.2) ...
# Preparing to unpack .../01-libdbus-1-3_1.12.2-1ubuntu1.3_amd64.deb ...
# Unpacking libdbus-1-3:amd64 (1.12.2-1ubuntu1.3) over (1.12.2-1ubuntu1.2) ...
# Selecting previously unselected package libibus-1.0-5:amd64.
# Preparing to unpack .../02-libibus-1.0-5_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking libibus-1.0-5:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package gir1.2-ibus-1.0:amd64.
# Preparing to unpack .../03-gir1.2-ibus-1.0_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package libcapnp-0.6.1:amd64.
# Preparing to unpack .../04-libcapnp-0.6.1_0.6.1-1ubuntu1_amd64.deb ...
# Unpacking libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../05-libdbus-1-dev_1.12.2-1ubuntu1.3_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.2-1ubuntu1.3) ...
# Selecting previously unselected package libibus-1.0-dev:amd64.
# Preparing to unpack .../06-libibus-1.0-dev_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking libibus-1.0-dev:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package libmircore1:amd64.
# Preparing to unpack .../07-libmircore1_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircommon7:amd64.
# Preparing to unpack .../08-libmircommon7_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-lite10:amd64.
# Preparing to unpack .../09-libprotobuf-lite10_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libmirprotobuf3:amd64.
# Preparing to unpack .../10-libmirprotobuf3_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient9:amd64.
# Preparing to unpack .../11-libmirclient9_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircore-dev:amd64.
# Preparing to unpack .../12-libmircore-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-dev:amd64.
# Preparing to unpack .../13-libprotobuf-dev_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../14-libxkbcommon-dev_0.8.2-1~ubuntu18.04.1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Selecting previously unselected package libmircommon-dev:amd64.
# Preparing to unpack .../15-libmircommon-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie2:amd64.
# Preparing to unpack .../16-libmircookie2_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie-dev:amd64.
# Preparing to unpack .../17-libmircookie-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient-dev:amd64.
# Preparing to unpack .../18-libmirclient-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libpulse-mainloop-glib0:amd64.
# Preparing to unpack .../19-libpulse-mainloop-glib0_1%3a11.1-1ubuntu7.11_amd64.deb ...
# Unpacking libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.11) ...
# Selecting previously unselected package libpulse-dev:amd64.
# Preparing to unpack .../20-libpulse-dev_1%3a11.1-1ubuntu7.11_amd64.deb ...
# Unpacking libpulse-dev:amd64 (1:11.1-1ubuntu7.11) ...
# Selecting previously unselected package libsndio-dev:amd64.
# Preparing to unpack .../21-libsndio-dev_1.1.0-3_amd64.deb ...
# Unpacking libsndio-dev:amd64 (1.1.0-3) ...
# Selecting previously unselected package libudev-dev:amd64.
# Preparing to unpack .../22-libudev-dev_237-3ubuntu10.53_amd64.deb ...
# Unpacking libudev-dev:amd64 (237-3ubuntu10.53) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../23-libxcursor-dev_1%3a1.1.15-1_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.1.15-1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../24-x11proto-xinerama-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xinerama-dev (2018.4-4) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../25-libxinerama-dev_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../26-x11proto-randr-dev_2018.4-4_all.deb ...
# Unpacking x11proto-randr-dev (2018.4-4) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../27-libxrandr-dev_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.1-1) ...
# Selecting previously unselected package libxv-dev:amd64.
# Preparing to unpack .../28-libxv-dev_2%3a1.0.11-1_amd64.deb ...
# Unpacking libxv-dev:amd64 (2:1.0.11-1) ...
# Selecting previously unselected package libsdl2-dev:amd64.
# Preparing to unpack .../29-libsdl2-dev_2.0.8+dfsg1-1ubuntu1.18.04.4_amd64.deb ...
# Unpacking libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Selecting previously unselected package libsdl2-gfx-1.0-0:amd64.
# Preparing to unpack .../30-libsdl2-gfx-1.0-0_1.0.4+dfsg-1_amd64.deb ...
# Unpacking libsdl2-gfx-1.0-0:amd64 (1.0.4+dfsg-1) ...
# Selecting previously unselected package libsdl2-gfx-dev:amd64.
# Preparing to unpack .../31-libsdl2-gfx-dev_1.0.4+dfsg-1_amd64.deb ...
# Unpacking libsdl2-gfx-dev:amd64 (1.0.4+dfsg-1) ...
# Selecting previously unselected package libsdl2-ttf-2.0-0:amd64.
# Preparing to unpack .../32-libsdl2-ttf-2.0-0_2.0.14+dfsg1-2_amd64.deb ...
# Unpacking libsdl2-ttf-2.0-0:amd64 (2.0.14+dfsg1-2) ...
# Selecting previously unselected package libsdl2-ttf-dev:amd64.
# Preparing to unpack .../33-libsdl2-ttf-dev_2.0.14+dfsg1-2_amd64.deb ...
# Unpacking libsdl2-ttf-dev:amd64 (2.0.14+dfsg1-2) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Setting up libsdl2-gfx-1.0-0:amd64 (1.0.4+dfsg-1) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.11) ...
# Setting up libpulse-dev:amd64 (1:11.1-1ubuntu7.11) ...
# Setting up libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libsndio-dev:amd64 (1.1.0-3) ...
# Setting up libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Setting up x11proto-xinerama-dev (2018.4-4) ...
# Setting up x11proto-randr-dev (2018.4-4) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1) ...
# Setting up libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Setting up libibus-1.0-5:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libsdl2-ttf-2.0-0:amd64 (2.0.14+dfsg1-2) ...
# Setting up libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libudev-dev:amd64 (237-3ubuntu10.53) ...
# Setting up libdbus-1-3:amd64 (1.12.2-1ubuntu1.3) ...
# Setting up libdbus-1-dev:amd64 (1.12.2-1ubuntu1.3) ...
# Setting up gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libibus-1.0-dev:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Setting up dbus (1.12.2-1ubuntu1.3) ...
# Setting up libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Setting up libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Setting up libsdl2-ttf-dev:amd64 (2.0.14+dfsg1-2) ...
# Setting up libsdl2-gfx-dev:amd64 (1.0.4+dfsg-1) ...
# Processing triggers for systemd (237-3ubuntu10.53) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Cloning into 'football'...
# remote: Enumerating objects: 3173, done.
# remote: Counting objects: 100% (232/232), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 3173 (delta 103), reused 206 (delta 93), pack-reused 2941
# Receiving objects: 100% (3173/3173), 27.29 MiB | 25.20 MiB/s, done.
# Resolving deltas: 100% (1785/1785), done.
# --2022-05-18 14:51:23--  https://storage.googleapis.com/gfootball/prebuilt_gameplayfootball_v2.8.so
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.20.128, 108.177.98.128, 74.125.197.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.20.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45403632 (43M) [application/octet-stream]
# Saving to: ‘football/third_party/gfootball_engine/lib/prebuilt_gameplayfootball.so’
#
# football/third_part 100%[===================>]  43.30M  72.2MB/s    in 0.6s
#
# 2022-05-18 14:51:24 (72.2 MB/s) - ‘football/third_party/gfootball_engine/lib/prebuilt_gameplayfootball.so’ saved [45403632/45403632]
#
# Processing /content/football
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Collecting pygame>=1.9.6
#   Downloading pygame-2.1.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.8 MB)
#      |████████████████████████████████| 21.8 MB 9.0 MB/s
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (4.1.2.30)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (5.4.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (1.21.6)
# Requirement already satisfied: gym<=0.21.0 in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (0.17.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (1.0.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from gfootball==2.10.3) (0.37.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym<=0.21.0->gfootball==2.10.3) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym<=0.21.0->gfootball==2.10.3) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym<=0.21.0->gfootball==2.10.3) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym<=0.21.0->gfootball==2.10.3) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py->gfootball==2.10.3) (1.15.0)
# Building wheels for collected packages: gfootball
#   Building wheel for gfootball (setup.py) ... done
#   Created wheel for gfootball: filename=gfootball-2.10.3-cp37-cp37m-linux_x86_64.whl size=24207444 sha256=cdd6cc017b84e9447fb04552df7f4f6c3b5ebc432db875bdc0fe0910db4fb303
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ua0tjioc/wheels/bb/c2/92/82a23d0c207f5497a23f4316675eb1629e6be474bd2c3be61a
# Successfully built gfootball
# Installing collected packages: pygame, gfootball
# Successfully installed gfootball-2.10.3 pygame-2.1.2
# Collecting utils
#   Downloading utils-1.0.1-py2.py3-none-any.whl (21 kB)
# Installing collected packages: utils
# Successfully installed utils-1.0.1

# %%
#from gfootball.env.football_env import FootballEnv
#from kaggle_environments import make
from gfootball.env.config import Config
import gfootball.env as football_env

#import dqn libraries
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim 
import numpy as np
import pandas as pd
import itertools
import utils
import random
from collections import deque
import matplotlib.pyplot as plt
#from utils import plot_learning_curve
#import env 
import gym
import gfootball 
import math

# %%
env = football_env.create_environment(env_name ='academy_empty_goal',render=False,representation='simple115v2')

new_observation,reward,done,info = env.step(5)
print(new_observation)
# Out:
# [ 1.1728146e-03  7.7794542e-11  3.4123159e-03  2.5766667e-11
#   2.0000000e-02 -0.0000000e+00  1.1059734e-01 -0.0000000e+00
#   0.0000000e+00 -1.9182914e-03]

# %%
class DeepQNetwork(nn.Module):
  def __init__(self,lr,input_dims,fc1_dims,fc2_dims,n_actions):
    super(DeepQNetwork,self).__init__()
   # self.lr=lr
    self.input_dims=input_dims
    self.fc1_dims=fc1_dims
    self.fc2_dims=fc2_dims
    
    self.n_actions=n_actions
    
    self.fc1=nn.Linear(*self.input_dims,self.fc1_dims) #pass list of observations as input
    self.fc2=nn.Linear(self.fc1_dims,self.fc2_dims)
    self.fc3=nn.Linear(self.fc2_dims,self.n_actions)
    #self.fc4=nn.Linear(self.fc3_dims,self.n_actions) #output number action

    self.optimizer = optim.Adam(self.parameters(),lr=lr)
    self.loss=nn.MSELoss()
    self.device =T.device('cuda:0' if T.cuda.is_available() else 'cpu' )
    self.to(self.device)

  def forward(self,state):
   
    x=F.relu(self.fc1(state))
    x=F.relu(self.fc2(x))
    actions=self.fc3(x)
    #x=F.relu(self.fc3(x))
    return actions

# %%
class All_prints():
  
  def __init___(self,step):
    self.step=step
    #self.RewBuffer = RewBuffer
    self.reward=reward

  def printstats(self,step,rew_list,eps_reward,epsilon):  #Kaleitai otan ginei done , diladi otan teleiosei ena paixnidi
    self.step=step
    self.rew_list=rew_list
    self.eps_reward=eps_reward
    self.epsilon=epsilon
    print("-->Episode:",i%3000 + 1,"\t","Episode Reward:",eps_reward,"\t Epsilon",agent.epsilon,"<--")
    #print("Step",step)
    print("lista apo rewards mexri tora" ,self.rew_list)
    print("Avg reward", np.mean(self.rew_list))
    print("---------------------------------------------------")

  def print_who_scored(self, reward):
    self.reward=reward
    if(self.reward==1):
      print("our team scored !!!")
    elif(self.reward ==-1):
      print("opponent team scored")
    
    
 
  def rew_graph(self,rew_list,num_of_eps):
      self.rew_list=rew_list
      
      self.num_of_eps=num_of_eps
      
      eps_list=list(range(1,self.num_of_eps+1))#pairnei to proto , den pairnei to teleytaio
      
      plt.plot(eps_list,self.rew_list)
      plt.xlabel('Episode')
      plt.ylabel('Rewards')
      plt.grid(True)
      plt.show()

  def step_graph(self,step_list,num_of_eps):
      self.step_list=step_list
      
      self.num_of_eps=num_of_eps
      
      eps_list=list(range(1,self.num_of_eps+1))#pairnei to proto , den pairnei to teleytaio
      
      plt.plot(eps_list,self.step_list)
      plt.xlabel('Episodes')
      plt.ylabel('Steps_to_score')
      plt.grid(True)
      plt.show()


  def score_graph(self,score_list,num_of_eps):
      self.score_list=score_list
      
      self.num_of_eps=num_of_eps
      
      eps_list=list(range(1,self.num_of_eps+1))#pairnei to proto , den pairnei to teleytaio
      
      plt.plot(eps_list,self.score_list)
      plt.xlabel('Episode')
      plt.ylabel('Score')
      plt.grid(True)
      plt.show()

# %%
class Agent():
  def __init__(self,gamma,epsilon, lr , input_dims , batch_size ,n_actions, max_mem_size = 10000  , eps_end=0.01 , eps_dec = 5e-4):
    self.gamma=gamma
    self.epsilon =epsilon
    self.lr=lr
    self.eps_min=eps_end
    self.eps_dec=eps_dec
   
    self.action_space =[i for i in range(n_actions)]
    self.mem_size = max_mem_size
    self.batch_size = batch_size
    #self.n_actions=n_actions
    self.mem_cntr =0 # keep track of the position of first available memory 

    self.Q_eval = DeepQNetwork(self.lr,n_actions=n_actions,input_dims= input_dims, fc1_dims=123, fc2_dims=123)

    self.state_memory = np.zeros((self.mem_size,*input_dims),dtype =np.float32)
    self.new_state_memory= np.zeros((self.mem_size , *input_dims),dtype=np.float32)

    self.action_memory=np.zeros(self.mem_size , dtype=np.int32) #discrete actions 
    self.reward_memory=np.zeros(self.mem_size,dtype= np.float32)
    self.terminal_memory= np.zeros(self.mem_size,dtype=bool)


  def store_transition(self,state,action,reward,new_state , done ):
    index = self.mem_cntr% self.mem_size

    self.state_memory[index]= state
    self.new_state_memory[index]= new_state
    self.reward_memory[index]= reward
    self.action_memory[index]= action  #which action is taken 
    self.terminal_memory[index]= done

    self.mem_cntr +=1
    

  def choose_action(self,observation):
    if np.random.random()> self.epsilon:
      
      state =T.tensor([observation]).to(self.Q_eval.device) #turn observation to tensor and send it to device for computations
      action_list = self.Q_eval.forward(state) #returns the values of each action
      action = T.argmax(action_list).item()
      #print("exploit:",action)
    else:     #
      
      action = np.random.choice(self.action_space)
      #print("explore:",action)
    return action

  def learn(self):    #fill batch size then learn 
    if self.mem_cntr < self.batch_size :
     
      return
    
    
    self.Q_eval.optimizer.zero_grad()

    #calculate the position of max memory / extract subset of max memories
    max_mem =min(self.mem_cntr , self.mem_size)
    


    batch=np.random.choice(max_mem,self.batch_size,replace=False) #We dont keep selecting the same memories more than once
     
    #batch = np.random.permutation(max_mem)[:self.batch_size]
    #mem = np.array(exp_buffer)[perm_batch]

    #batch=np.random.choice(max_mem,self.batch_size,replace=False)
    batch_index = np.arange(self.batch_size , dtype=np.int32)

    state_batch=T.tensor(self.state_memory[batch]).to(self.Q_eval.device) #make numpy array a pytorch tensor
    new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
    reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
    terminal_batch= T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)

    action_batch = self.action_memory[batch] 
  
    q_eval = self.Q_eval.forward(state_batch)[batch_index,action_batch] #EXEI THEMA
    q_next = self.Q_eval.forward(new_state_batch)

    q_next[terminal_batch] = 0.0
    q_target = reward_batch +self.gamma * T.max(q_next,dim=1)[0] #max value of next state

    loss = self.Q_eval.loss(q_target,q_eval).to(self.Q_eval.device)
    loss.backward()
    self.Q_eval.optimizer.step()

    self.epsilon = self.epsilon - self.eps_dec if (self.epsilon > self.eps_min)  else self.eps_min

# %%
 
env = football_env.create_environment(env_name ='academy_empty_goal',render=False,representation='simple115v2')  #List with the 115 states 


#CUSTOMIZE ACTION LIST AND OBSERVATIONS
Action_list=[4,5,6,12]

#Create Objects

agent = Agent(gamma=0.99,epsilon=1.0 ,batch_size = 64 ,lr=0.00115 ,input_dims= [10], n_actions = len(Action_list) )# batch = best 256
all_prints = All_prints()
#cus_rew =Custom_Rewards()

scores,ep_history =[],[]

steps=0
terminal =0
episode =0
shout =0


num_of_eps = 601
eps_rew=0
rew_list =[]
score_list = []
step_list =[]
goal_steps=[]
for i in range(num_of_eps) : 
  score =0 
  done=False 
  observation =env.reset()
  act =0 #first action will be to move right 
  shout=0 #mporei na kanei shout 1 fora se kathe ep
  while not done:

    #CUSTOMIZE ACTIONS HERE 
    #An einai i mpala sto 0.5 kai exo katoxi kane shout diladi action 12
    
    #print("------------")
    #print("Ball X-Y-Z Axis",observation[88],observation[89],observation[90],"||","direct",observation[91],observation[92],observation[93],"Katoxi",observation[95],observation[96])
    #print("Player X-Axis Y-Axis",observation[2],observation[3] ,"episode",i) SOSTO
    #print("------------")



   
     
      
 
    if(act ==0 ): # proti praksi ena bima deksia
      
      # print("action 5",Action_list[action])
      new_observation,reward,done,info = env.step(5)
      
      act=1
      #print(new_observation)
    #print("Sto Else",observation[94],observation[95],observation[96])
    

    #CUSTOM ACTIONS
    action = agent.choose_action(observation) # from 1-4 which is index to action list

    while((observation[0]<0.65)  and (Action_list[action]==12)): #Den kanei shout ektos periohis
      action = agent.choose_action(observation)
     
      #print("Player Position:",observation[0],observation[1])
      #print("Player Direction:",observation[2],observation[3])
      #print("Ball Position:",observation[4],observation[5],observation[6])
      #print("Ball Direction:",observation[7],observation[8],observation[9])

    if(shout==0):   #ama kanei shout na min kanei tipota meta 
      new_observation,reward,done,info = env.step(Action_list[action])
      
      if(Action_list[action]==12):
        #print("EKANE SHOUT")
        shout=1
    else:
      #print("MPIKE STO ELSE")
      new_observation,reward,done,info = env.step(0)
      action=0 #Ta parakato if den pianoun to Action_list[action]=12 alla gia Action_list[action]=4

   
    
    
    #CUSTOM REWARDS
    
    if(done ==1 and reward != 1): #if ball is out ,loses -2
      #print("Ball is out reward:",reward)
      reward = reward -10 #12
      print("ball is out -10","episode",i,"Ball Position",observation[4],observation[5],observation[6],"step=",steps)
      terminal =0


    if(reward==1 and  done ==1): #if agent scores , wins +5
      print("goal","episode",i,"step=",steps)
      reward += 35 #35


      terminal= terminal +1
      goal_steps.append(steps)

    if((observation[0]<0.5)  and (Action_list[action]==12)): #an shoutarei prin th megali perioxh -2
      
      reward= reward -200
      done=1
      print("shout ektos periohis","episode",i,"step=",steps)
      
    if((observation[0]>0.6) and (Action_list[action]==12)): #an shoutarei mesa ti megali periohi +0.1
      #reward= reward +0.1
      print("shout entos periohis Ball Position",observation[4],observation[5],observation[6],"episode",i,"step=",steps)
      
    
    reward = reward - ( math.sqrt( ((0.935 - observation[4])**2) + (0 -observation[5])**2 ) *0.3) #oso pio makria einai toso perissotero xanei
    #print("Den exo mpala",Action_list[action])
    #print("DEN EXO MPALA",Action_list[action],action)

    #custom reward here
 
    
   
    score+= reward

    #for prints
    eps_rew+=reward
    #all_prints.print_who_scored(reward)
    

    agent.store_transition(observation,action,reward,new_observation,done)
    agent.learn()
    observation = new_observation

    scores.append(score)
    ep_history.append(agent.epsilon)

    avg_score= np.mean(scores)


    steps=steps+1
    
#---- BE CAREFUL OF THE WHILE !!! HERE IS EPIDOSE ENDING--------
  #print("Reward",eps_rew,"Episode",i,"Steps" , steps)
  step_list.append(steps)
  steps=0

  val = info.values()
  list_val=list(val)
  score_list.append(list_val)
  
  #terminate if 500 episodes are correct 
  if(terminal ==25):
    print("!!! END OF TRAINING 20 CONTINUOUS GOALS !!!")
    print("---Avg reward last:", np.mean(rew_list[-10:]),"Avg score last",np.mean(score_list[-10:]),"Avg steps",np.mean(step_list[-10:]),"episode=",i,"---")
    all_prints.rew_graph(rew_list[-i:],i)
    all_prints.step_graph(goal_steps[-20:],20)
    break

  episode = episode +1 
  rew_list.append(eps_rew)

# PRINTS
  if (i % 10)== 0 :
      print("---Avg reward last:", np.mean(rew_list[-10:]),"Avg score last",np.mean(score_list[-10:]),"Avg steps",np.mean(step_list[-10:]),"episode=",i,"---")
      #print(score_list)

  if (((i % 1000)== 0) and i!=0) :
      all_prints.score_graph(score_list[-1000:],1000)# graph the last 1000 episodes
  if(((i%50)==0) and i!=0):
    all_prints.rew_graph(rew_list[-i:],i)
     
  
  #EPISODE PRINTS
  #all_prints.printstats(i,rew_list,eps_rew,agent.epsilon)
  
  #eps_rew=0 #GIA NA BGALO SYNOLIKO GRAFIMA TO AFAIRO AYTO



#print("Avg score last:", np.mean(rew_list[-10:]),"Avg score",np.mean(score_list),"Avg steps",np.mean(step_list[-10:]),"episode=",i)
#all_prints.score_graph(score_list[-1000:],1000)# graph the last 1000 episodes
      
a = len(goal_steps)
all_prints.step_graph(goal_steps[-a:],len(goal_steps))
# Out:
# shout entos periohis Ball Position 0.68786275 0.056654867 0.12492595 episode 0 step= 103
# goal episode 0 step= 113
# ---Avg reward last: 17.041101183145837 Avg score last 1.0 Avg steps 114.0 episode= 0 ---
# shout entos periohis Ball Position 0.6780468 -0.100696415 0.12272509 episode 1 step= 105
# ball is out -10 episode 1 Ball Position 1.0038099 -0.047606364 0.20202926 step= 115
# shout entos periohis Ball Position 0.66139156 -0.06236937 0.11071116 episode 2 step= 103
# goal episode 2 step= 116
# shout entos periohis Ball Position 0.657866 0.008975539 0.11079608 episode 3 step= 108
# goal episode 3 step= 119
# shout entos periohis Ball Position 0.66162336 -0.019544318 0.11122473 episode 4 step= 110
# goal episode 4 step= 120
# shout entos periohis Ball Position 0.68227535 0.0046820655 0.1312473 episode 5 step= 106
# goal episode 5 step= 116
# shout entos periohis Ball Position 0.6714713 -0.03394358 0.118990146 episode 6 step= 105
# ball is out -10 episode 6 Ball Position 0.99129707 -0.064529486 0.5730105 step= 115
# shout entos periohis Ball Position 0.67512685 0.059159767 0.1125308 episode 7 step= 107
# ball is out -10 episode 7 Ball Position 1.0209892 0.05433697 0.19077696 step= 120
# shout entos periohis Ball Position 0.7074634 -0.0490562 0.11565104 episode 8 step= 105
# ball is out -10 episode 8 Ball Position 1.0065868 -0.053074855 0.14100671 step= 117
# shout entos periohis Ball Position 0.68449473 -0.042249918 0.11090539 episode 9 step= 114
# ball is out -10 episode 9 Ball Position 0.9964201 -0.055569217 0.1390909 step= 125
# shout entos periohis Ball Position 0.69622725 -0.026736496 0.108146265 episode 10 step= 107
# goal episode 10 step= 116
# ---Avg reward last: -4.288233331439999 Avg score last 0.5 Avg steps 118.9 episode= 10 ---
# shout entos periohis Ball Position 0.6812269 0.0068760994 0.110374235 episode 11 step= 106
# ball is out -10 episode 11 Ball Position 1.0197816 0.05596436 0.23218389 step= 117
# shout entos periohis Ball Position 0.65943956 -0.02433897 0.112529986 episode 12 step= 101
# ball is out -10 episode 12 Ball Position 1.0033871 -0.046146717 0.63338554 step= 112
# shout entos periohis Ball Position 0.78112835 0.043196674 0.11346359 episode 13 step= 115
# goal episode 13 step= 122
# shout entos periohis Ball Position 0.6625572 -0.032418683 0.13030738 episode 14 step= 105
# goal episode 14 step= 115
# shout entos periohis Ball Position 0.7129646 -0.057535008 0.12928438 episode 15 step= 105
# goal episode 15 step= 116
# shout entos periohis Ball Position 0.703644 -0.022953905 0.12582432 episode 16 step= 102
# goal episode 16 step= 112
# goal episode 17 step= 150
# goal episode 18 step= 149
# shout entos periohis Ball Position 0.6970565 -0.022559041 0.113068834 episode 19 step= 109
# goal episode 19 step= 118
# goal episode 20 step= 143
# ---Avg reward last: -46.776252380179926 Avg score last 0.8 Avg steps 126.4 episode= 20 ---
# ball is out -10 episode 21 Ball Position 1.0076867 0.07093824 0.110157475 step= 156
# shout entos periohis Ball Position 0.6776216 -0.013788976 0.11716081 episode 22 step= 106
# goal episode 22 step= 115
# goal episode 23 step= 159
# goal episode 24 step= 163
# ball is out -10 episode 25 Ball Position 1.0145873 0.10238884 0.11201865 step= 148
# shout entos periohis Ball Position 0.91159695 -0.011556518 0.11110019 episode 26 step= 141
# goal episode 26 step= 146
# shout entos periohis Ball Position 0.7117539 0.015979506 0.12913893 episode 27 step= 111
# goal episode 27 step= 119
# shout entos periohis Ball Position 0.9174142 0.04824243 0.11871943 episode 28 step= 141
# ball is out -10 episode 28 Ball Position 0.9934845 0.064240366 0.56292766 step= 146
# goal episode 29 step= 156
# shout entos periohis Ball Position 0.6680312 0.0057535595 0.1222553 episode 30 step= 95
# goal episode 30 step= 106
# ---Avg reward last: 23.739812045913176 Avg score last 0.7 Avg steps 142.4 episode= 30 ---
# shout entos periohis Ball Position 0.87616193 0.09771236 0.111527555 episode 31 step= 138
# goal episode 31 step= 144
# shout entos periohis Ball Position 0.6694342 0.020520624 0.113772035 episode 32 step= 96
# goal episode 32 step= 105
# shout entos periohis Ball Position 0.664835 0.08992523 0.1106198 episode 33 step= 98
# goal episode 33 step= 109
# shout entos periohis Ball Position 0.6648929 0.18707915 0.11863577 episode 34 step= 98
# ball is out -10 episode 34 Ball Position 1.0025054 0.062448625 0.19466656 step= 111
# goal episode 35 step= 141
# shout entos periohis Ball Position 0.9088809 0.25225803 0.11327493 episode 36 step= 128
# ball is out -10 episode 36 Ball Position 1.0114374 0.14758942 0.5558943 step= 137
# shout entos periohis Ball Position 0.76129436 0.1618748 0.12012155 episode 37 step= 104
# ball is out -10 episode 37 Ball Position 1.0089489 0.07438963 0.53286266 step= 115
# shout entos periohis Ball Position 0.8070996 0.12302118 0.1262084 episode 38 step= 119
# ball is out -10 episode 38 Ball Position 1.0008134 0.09982212 1.3525171 step= 127
# shout entos periohis Ball Position 0.9966452 0.1959326 0.112328134 episode 39 step= 140
# ball is out -10 episode 39 Ball Position 1.0089451 0.20439029 0.12889746 step= 142
# shout entos periohis Ball Position 0.81271815 0.12295749 0.12141391 episode 40 step= 103
# ball is out -10 episode 40 Ball Position 0.88859797 -0.2938092 0.109780006 step= 399
# ---Avg reward last: 34.12494869975613 Avg score last 0.4 Avg steps 154.0 episode= 40 ---
# ball is out -10 episode 41 Ball Position 1.0138779 -0.045631457 0.13287812 step= 158
# ball is out -10 episode 42 Ball Position 1.0125935 0.13436916 0.11142517 step= 141
# ball is out -10 episode 43 Ball Position 1.0124044 -0.05795363 0.10785258 step= 162
# shout entos periohis Ball Position 0.68191606 0.081951454 0.12582783 episode 44 step= 94
# goal episode 44 step= 103
# shout entos periohis Ball Position 0.7093784 0.020383818 0.11567476 episode 45 step= 108
# goal episode 45 step= 119
# goal episode 46 step= 153
# goal episode 47 step= 154
# ball is out -10 episode 48 Ball Position 1.0103292 -0.06948464 0.12914072 step= 165
# goal episode 49 step= 131
# goal episode 50 step= 167
# ---Avg reward last: -137.48013084735203 Avg score last 0.6 Avg steps 146.3 episode= 50 ---
# ball is out -10 episode 51 Ball Position 1.0120444 -0.05825699 0.11136213 step= 149
# shout entos periohis Ball Position 0.7934927 -0.0065492163 0.1105451 episode 52 step= 123
# goal episode 52 step= 130
# ball is out -10 episode 53 Ball Position 1.0095812 -0.057895042 0.114786595 step= 153
# shout entos periohis Ball Position 0.8065756 -0.020921664 0.112518586 episode 54 step= 115
# goal episode 54 step= 121
# goal episode 55 step= 150
# shout entos periohis Ball Position 0.9530044 -0.03132142 0.11925811 episode 56 step= 151
# ball is out -10 episode 56 Ball Position 0.98167217 -0.04363782 0.15552111 step= 154
# goal episode 57 step= 144
# shout entos periohis Ball Position 0.66573644 -0.0834643 0.11349775 episode 58 step= 100
# goal episode 58 step= 111
# goal episode 59 step= 159
# goal episode 60 step= 148
# ---Avg reward last: -126.8977669628747 Avg score last 0.7 Avg steps 142.9 episode= 60 ---
# goal episode 61 step= 143
# goal episode 62 step= 153
# goal episode 63 step= 158
# goal episode 64 step= 149
# shout entos periohis Ball Position 0.66293544 -0.12071671 0.11061193 episode 65 step= 103
# goal episode 65 step= 114
# goal episode 66 step= 165
# shout entos periohis Ball Position 0.7841266 0.032109555 0.11480759 episode 67 step= 113
# goal episode 67 step= 121
# goal episode 68 step= 156
# goal episode 69 step= 155
# goal episode 70 step= 168
# ---Avg reward last: 7.071753914948443 Avg score last 1.0 Avg steps 149.2 episode= 70 ---
# shout entos periohis Ball Position 0.9167096 0.0061627375 0.11071123 episode 71 step= 136
# goal episode 71 step= 142
# shout entos periohis Ball Position 0.661128 -0.093262754 0.11082906 episode 72 step= 100
# goal episode 72 step= 112
# goal episode 73 step= 162
# goal episode 74 step= 168
# shout entos periohis Ball Position 0.9566196 -0.011372191 0.10925605 episode 75 step= 145
# goal episode 75 step= 151
# goal episode 76 step= 152
# shout entos periohis Ball Position 0.92156553 0.017965393 0.11493401 episode 77 step= 129
# goal episode 77 step= 134
# goal episode 78 step= 160
# goal episode 79 step= 149
# shout entos periohis Ball Position 0.79504967 -0.0054396 0.12512785 episode 80 step= 111
# ball is out -10 episode 80 Ball Position 1.0182419 0.045011282 0.32794014 step= 120
# ---Avg reward last: 162.17013634222567 Avg score last 0.9 Avg steps 146.0 episode= 80 ---
# shout entos periohis Ball Position 0.66126615 -0.1377443 0.11881452 episode 81 step= 110
# goal episode 81 step= 123
# goal episode 82 step= 150
# goal episode 83 step= 144
# shout entos periohis Ball Position 0.750821 0.017234802 0.11064761 episode 84 step= 105
# goal episode 84 step= 115
# goal episode 85 step= 141
# shout entos periohis Ball Position 0.7238174 0.017593337 0.12430923 episode 86 step= 107
# goal episode 86 step= 117
# goal episode 87 step= 148
# goal episode 88 step= 167
# goal episode 89 step= 160
# goal episode 90 step= 156
# ---Avg reward last: 287.0019433149601 Avg score last 1.0 Avg steps 143.1 episode= 90 ---
# goal episode 91 step= 173
# goal episode 92 step= 144
# shout entos periohis Ball Position 0.9019737 0.01060788 0.1119414 episode 93 step= 119
# goal episode 93 step= 123
# goal episode 94 step= 161
# shout entos periohis Ball Position 0.7577324 0.022283744 0.11320478 episode 95 step= 101
# goal episode 95 step= 109
# goal episode 96 step= 145
# shout entos periohis Ball Position 0.9880468 0.015146496 0.110749684 episode 97 step= 143
# goal episode 97 step= 147
# shout entos periohis Ball Position 0.66241705 -0.0028978095 0.11057707 episode 98 step= 98
# goal episode 98 step= 110
# shout entos periohis Ball Position 0.80097324 0.0085144285 0.11108628 episode 99 step= 109
# goal episode 99 step= 116
# goal episode 100 step= 159
# ---Avg reward last: 450.8030031907903 Avg score last 1.0 Avg steps 139.7 episode= 100 ---
# shout entos periohis Ball Position 0.7544095 0.02131702 0.119811095 episode 101 step= 110
# goal episode 101 step= 120
# goal episode 102 step= 163
# shout entos periohis Ball Position 0.8127909 0.005051136 0.11305718 episode 103 step= 132
# goal episode 103 step= 140
# goal episode 104 step= 158
# goal episode 105 step= 151
# !!! END OF TRAINING 20 CONTINUOUS GOALS !!!
# ---Avg reward last: 518.5800594673474 Avg score last 1.0 Avg steps 141.9 episode= 105 ---

# %%
a = len(goal_steps)
all_prints.step_graph(goal_steps[-a:],len(goal_steps))

# %%
class Custom_Rewards():
  #def __init__(self):
    #self.obs=obs    
    #self.action=action
    #self.reward =reward
  def custom_rew(self,obs,action,reward,new_obs):
    
    self.obs=obs
    self.action = action
    self.reward = reward
    self.new_obs=new_obs
    
    
#if the next action is shooting the ball, the reward will gain 0.2 point ||
#an exo ti mpala kai einai se apostasi x > 0.5 sto gipedo kai exei kanei shout einai kalo    
    if(self.obs[95] == 1 and self.obs[88] > 0.6 and self.action == 12):
      self.reward += 0.02
      #print("EKANE SHOUT MPROSTA APO TO KENTRO ,+0.1")
      return self.reward

    #An kanei shout piso apo to kentro na xanei ligo
    elif(self.obs[95]==1 and self.obs[88] < 0 and self.action == 12):
      self.reward -= 0.02
      #print("EKANE SHOUT PISO APO TO KENTRO, -0.05")
      return self.reward

# if we steal the ball, the reward will gain 0.05 points
    elif self.obs[96] == 1 and self.new_obs[95] == 1:  #obs[96] ball owner right team / obs[95] ball owner left team
        self.reward += 0.05
        #print("PHRE THN MPALA APO TON ANTIPALO , +0.05")
        return self.reward
#if we lose the ball, the reward will lose 0.05 points
    elif self.obs[95] == 1 and self.new_obs[96] == 1:
        self.reward -=0.02
        #print("PHRE THN MPALA O ANTIPALOS , -0.02")
        return self.reward
    else:
      return self.reward


#TODO: if active player far from the ball, the reward will lose by the moving distance

# %%
#print(score_list or reward_list)

# %%
"""print(observation)
new_observation,reward,done,info = env.step(4)
print(new_observation)"""

# %%
# gpu_info = !nvidia-smi
# gpu_info = '\n'.join(gpu_info)
# if gpu_info.find('failed') >= 0:
#   print('Not connected to a GPU')
# else:
#   print(gpu_info)

# %%
"""env = football_env.create_environment(env_name ='academy_single_goal_versus_lazy',render=False,representation='simple115')
observation =env.reset()
new_observation,reward,done,info = env.step(action)
val=info.values()
print(val)
list_val=list(val)
list_val"""
